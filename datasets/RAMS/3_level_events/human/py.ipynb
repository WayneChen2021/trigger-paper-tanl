# %%
import json
from nltk.tokenize import TreebankWordTokenizer as tbwt

# %%
all_examples = []

for file in ['train', 'test', 'dev']:
    with open(f'{file}.json', 'r') as f:
        all_examples += list(json.loads(f.read()).values())

# %%
words_by_type = {}

# %%
for ex in all_examples:
    template = ex['templates'][0]
    incident_type = template['incident_type']
    tokens_spans = list(tbwt().span_tokenize(ex['doctext']))

    if not incident_type in words_by_type:
        words_by_type[incident_type] = {}
    
    for token_span in tokens_spans:
        normalized_span = ex['doctext'][token_span[0] : token_span[1]].strip().lower()
        if not normalized_span in words_by_type[incident_type]:
            words_by_type[incident_type][normalized_span] = 1
        else:
            words_by_type[incident_type][normalized_span] += 1

# %%
words_by_type.keys()
# Out:
# dict_keys(['life.die.deathcausedbyviolentevents', 'movement.transportartifact.hide', 'conflict.attack.selfdirectedbattle', 'life.injure.illnessdegradationphysical', 'contact.commitmentpromiseexpressintent.n/a', 'justice.arrestjaildetain.arrestjaildetain', 'contact.discussion.meet', 'life.injure.injurycausedbyviolentevents', 'personnel.endposition.n/a', 'transaction.transferownership.n/a', 'justice.investigate.investigatecrime', 'contact.collaborate.n/a', 'government.agreements.violateagreement', 'movement.transportperson.prevententry', 'contact.commandorder.broadcast', 'transaction.transfermoney.n/a', 'justice.initiatejudicialprocess.n/a', 'contact.prevarication.broadcast', 'conflict.attack.stealrobhijack', 'life.injure.illnessdegradationhungerthirst', 'contact.negotiate.meet', 'contact.threatencoerce.n/a', 'contact.commitmentpromiseexpressintent.broadcast', 'personnel.elect.n/a', 'transaction.transfermoney.purchase', 'contact.mediastatement.broadcast', 'contact.requestadvise.correspondence', 'movement.transportartifact.disperseseparate', 'government.legislate.legislate', 'movement.transportperson.preventexit', 'contact.negotiate.n/a', 'government.agreements.n/a', 'life.injure.n/a', 'justice.judicialconsequences.extradite', 'personnel.endposition.firinglayoff', 'justice.investigate.n/a', 'movement.transportartifact.sendsupplyexport', 'government.agreements.acceptagreementcontractceasefire', 'disaster.fireexplosion.fireexplosion', 'contact.collaborate.correspondence', 'transaction.transaction.transfercontrol', 'transaction.transfermoney.giftgrantprovideaid', 'movement.transportartifact.nonviolentthrowlaunch', 'contact.commitmentpromiseexpressintent.correspondence', 'conflict.attack.airstrikemissilestrike', 'government.formation.n/a', 'movement.transportperson.hide', 'justice.judicialconsequences.execute', 'transaction.transaction.embargosanction', 'conflict.attack.stabbing', 'conflict.yield.retreat', 'transaction.transfermoney.embargosanction', 'manufacture.artifact.build', 'inspection.sensoryobserve.n/a', 'justice.initiatejudicialprocess.trialhearing', 'movement.transportartifact.smuggleextract', 'contact.requestadvise.broadcast', 'contact.commitmentpromiseexpressintent.meet', 'government.spy.spy', 'government.vote.violationspreventvote', 'contact.discussion.n/a', 'contact.commandorder.correspondence', 'justice.judicialconsequences.n/a', 'conflict.attack.firearmattack', 'contact.prevarication.correspondence', 'movement.transportartifact.bringcarryunload', 'conflict.attack.strangling', 'contact.requestadvise.n/a', 'artifactexistence.damagedestroy.destroy', 'life.die.n/a', 'contact.threatencoerce.meet', 'personnel.startposition.hiring', 'conflict.attack.n/a', 'personnel.endposition.quitretire', 'justice.initiatejudicialprocess.chargeindict', 'contact.requestadvise.meet', 'government.formation.startgpe', 'transaction.transfermoney.payforservice', 'personnel.elect.winelection', 'movement.transportperson.grantentryasylum', 'movement.transportartifact.n/a', 'contact.publicstatementinperson.broadcast', 'contact.discussion.correspondence', 'movement.transportperson.disperseseparate', 'transaction.transferownership.purchase', 'movement.transportperson.n/a', 'conflict.demonstrate.n/a', 'conflict.demonstrate.marchprotestpoliticalgathering', 'movement.transportperson.smuggleextract', 'inspection.sensoryobserve.physicalinvestigateinspect', 'contact.publicstatementinperson.n/a', 'justice.judicialconsequences.convict', 'contact.funeralvigil.meet', 'manufacture.artifact.createmanufacture', 'conflict.yield.n/a', 'government.formation.mergegpe', 'transaction.transfermoney.borrowlend', 'transaction.transaction.n/a', 'transaction.transferownership.embargosanction', 'transaction.transaction.giftgrantprovideaid', 'artifactexistence.damagedestroy.damage', 'contact.prevarication.n/a', 'government.vote.n/a', 'conflict.attack.invade', 'contact.threatencoerce.correspondence', 'personnel.startposition.n/a', 'contact.funeralvigil.n/a', 'contact.threatenco ...

# %%
event_type = "movement.transportperson.n/a"
print(json.dumps({k: v for k, v in sorted(words_by_type[event_type].items(), key=lambda item: -1 * item[1])}, indent=4))
# Out:
# {
#     "the": 1140,
#     ",": 950,
#     ".": 711,
#     "of": 544,
#     "to": 514,
#     "and": 483,
#     "in": 470,
#     "a": 394,
#     "that": 199,
#     "-": 187,
#     "on": 174,
#     "is": 154,
#     "for": 142,
#     "\u201d": 138,
#     "\u201c": 136,
#     "it": 127,
#     "\"": 125,
#     "as": 121,
#     "\u2019s": 117,
#     "was": 116,
#     "said": 110,
#     "from": 109,
#     "by": 108,
#     "he": 105,
#     "has": 99,
#     "at": 98,
#     "with": 95,
#     "an": 92,
#     "have": 87,
#     "his": 79,
#     "they": 76,
#     "'s": 69,
#     "are": 69,
#     "not": 68,
#     "who": 68,
#     "were": 66,
#     "trump": 66,
#     "be": 63,
#     "but": 61,
#     "after": 55,
#     "their": 55,
#     "which": 52,
#     "this": 52,
#     "been": 52,
#     ":": 51,
#     "one": 50,
#     "russia": 48,
#     "i": 48,
#     "\u2014": 47,
#     "she": 47,
#     "people": 46,
#     "her": 46,
#     "or": 45,
#     ")": 45,
#     "(": 44,
#     "more": 42,
#     "clinton": 42,
#     "government": 42,
#     "russian": 41,
#     "we": 41,
#     "had": 40,
#     "would": 39,
#     "also": 38,
#     "about": 36,
#     "up": 35,
#     "syria": 35,
#     "when": 34,
#     "its": 33,
#     "what": 32,
#     "there": 32,
#     "u.s.": 32,
#     "will": 32,
#     "out": 31,
#     "over": 31,
#     "other": 31,
#     "police": 31,
#     "state": 30,
#     "all": 29,
#     "our": 29,
#     ";": 28,
#     "so": 27,
#     "told": 27,
#     "us": 26,
#     "some": 26,
#     "where": 26,
#     "president": 26,
#     "last": 26,
#     "can": 25,
#     "aleppo": 25,
#     "than": 24,
#     "country": 24,
#     "them": 24,
#     "into": 24,
#     "/": 24,
#     "only": 23,
#     "do": 23,
#     "military": 23,
#     "obama": 23,
#     "states": 23,
#     "you": 22,
#     "during": 22,
#     "'": 22,
#     "two": 22,
#     "year": 22,
#     "new": 21,
#     "even": 21,
#     "those": 21,
#     "just": 21,
#     "years": 21,
#     "if": 21,
#     "now": 21,
#     "between": 21,
#     "syrian": 21,
#     "officials": 21,
#     "first": 20,
#     "war": 20,
#     "human": 20,
#     "before": 20,
#     "no": 20,
#     "east": 20,
#     "city": 20,
#     "forces": 20,
#     "world": 20,
#     "department": 20,
#     "united": 20,
#     "countries": 20,
#     "like": 19,
#     "many": 19,
#     "back": 19,
#     "left": 19,
#     "turkey": 19,
#     "north": 19,
#     "since": 18,
#     "n\u2019t": 18,
#     "american": 18,
#     "both": 18,
#     "europe": 18,
#     "air": 17,
#     "news": 17,
#     "down": 17,
#     "while": 17,
#     "middle": 17,
#     "could": 17,
#     "rights": 17,
#     "did": 16,
#     "isis": 16,
#     "area": 16,
#     "most": 16,
#     "asylum": 16,
#     "against": 16,
#     "off": 16,
#     "moscow": 16,
#     "violence": 16,
#     "americans": 16,
#     "three": 16,
#     "him": 16,
#     "european": 15,
#     "time": 15,
#     "?": 15,
#     "women": 15,
#     "according": 15,
#     "refugees": 15,
#     "campaign": 15,
#     "political": 15,
#     "week": 15,
#     "man": 15,
#     "being": 15,
#     "here": 15,
#     "islamic": 15,
#     "because": 15,
#     "any": 15,
#     "central": 14,
#     "says": 14,
#     "how": 14,
#     "far": 14,
#     "criminal": 14,
#     "should": 14,
#     "border": 14,
#     "well": 14,
#     "these": 14,
#     "intelligence": 13,
#     "including": 13,
#     "america": 13,
#     "called": 13,
#     "hillary": 13,
#     "immigrants": 13,
#     "say": 13,
#     "may": 13,
#     "n't": 13,
#     "under": 13,
#     "such": 13,
#     "putin": 13,
#     "children": 12,
#     "$": 12,
#     "trafficking": 12,
#     "held": 12,
#     "right": 12,
#     "around": 12,
#     "killed": 12,
#     "born": 12,
#     "made": 12,
#     "crisis": 12,
#     "[": 12,
#     "]": 12,
#     "snowden": 12,
#     "through": 11,
#     "international": 11,
#     "fbi": 11,
#     "own": 11,
#     "supporters": 11,
#     "arrested": 11,
#     "2015": 11,
#     "foreign": 11,
#     "weapons": 11,
#     "university": 11,
#     "ago": 11,
#     "several": 11,
#     "way": 11,
#     "reuters": 11,
#     "oil": 11,
#     "iran": 11,
#     "\u2013": 11,
#     "al": 11,
#     "general": 11,
#     "anti": 11,
#     "group": 11,
#     "dead": 11,
#     "part": 11,
#     "old": 11,
#     "immigration": 11,
#     "email": 11,
#     "eastern": 11,
#     "video": 11,
#     "internet": 11,
#     "evidence": 10,
#     "thousands": 10,
#     "end": 10,
#     "think": 10,
#     "northern": 10,
#     "family": 10,
#     "few": 10,
#     "stop": 10,
#     "former": 10,
#     "young": 10,
#     "land": 10,
#     "borders": 10,
#     "attack": 10,
#     "whom": 10,
#     "administration": 10,
#     "day": 10,
#     "open": 10,
#     "national": 10,
#     "ad": 10,
#     "opposition": 10,
#     "month": 10,
#     "medical": 10,
#     "evacuated": 10,
#     "my": 10,
#     "later": 10,
#     "emails": 10,
#     "germany": 9,
#     "fled": 9,
#     "free": 9,
#     "escape": 9,
#     "official": 9,
#     "strike": 9,
#     "civilians": 9,
#     "want": 9,
#     "saying": 9,
#     "minister": 9,
#     "cruz": 9,
#     "attacks": 9,
#     "taken": 9,
#     "immigrated": 9,
#     "local": 9,
#     "whose": 9,
#     "system": 9,
#     "law": 9,
#     "terrorists": 9,
#     "ground": 9,
#     "case": 9,
#     "march": 9,
#     "trade": 9,
#     "agency": 9,
#     "times": 9,
#     "home": 9,
#     "allow": 9,
#     "really": 9,
#     "muslim": 9,
#     "death": 9,
#     "working": 9,
#     "army": 9,
#     "used": 9,
#     "place": 9,
#     "near": 9,
#     "already": 9,
#     "afp": 9,
#     "court": 9,
#     "2014": 9,
#     "rebel": 9,
#     "2016": 9,
#     "september": 9,
#     "become": 9,
#     "long": 9,
#     "security": 9,
#     "following": 9,
#     "\u2026": 9,
#     "look": 8,
#     "reports": 8,
#     "hit": 8,
#     "flee": 8,
#     "fleeing": 8,
#     "policy": 8,
#     "crime": 8,
#     "instead": 8,
#     "region": 8,
#     "work": 8,
#     "too": 8,
#     "brought": 8,
#     "members": 8,
#     "chinese": 8,
#     "public": 8,
#     "across": 8,
#     "\u2019": 8,
#     "evacuate": 8,
#     "does": 8,
#     "take": 8,
#     "pay": 8,
#     "having": 8,
#     "mass": 8,
#     "next": 8,
#     "real": 8,
#     "illegal": 8,
#     "crowd": 8,
#     "sunday": 8,
#     "report": 8,
#     "freedom": 8,
#     "south": 8,
#     "detained": 8,
#     "living": 8,
#     "airstrikes": 8,
#     "set": 8,
#     "photos": 8,
#     "make": 8,
#     "millions": 8,
#     "charges": 8,
#     "victims": 8,
#     "economic": 8,
#     "authorities": 8,
#     "iraq": 8,
#     "protests": 8,
#     "need": 8,
#     "captured": 8,
#     "found": 7,
#     "released": 7,
#     "least": 7,
#     "fighters": 7,
#     "families": 7,
#     "hundreds": 7,
#     "refugee": 7,
#     "know": 7,
#     "making": 7,
#     "million": 7,
#     "drug": 7,
#     "read": 7,
#     "your": 7,
#     "head": 7,
#     "going": 7,
#     "get": 7,
#     "support": 7,
#     "native": 7,
#     "allies": 7,
#     "ukraine": 7,
#     "men": 7,
#     "justice": 7,
#     "control": 7,
#     "given": 7,
#     "little": 7,
#     "known": 7,
#     "multiple": 7,
#     "sent": 7,
#     "norway": 7,
#     "run": 7,
#     "hand": 7,
#     "go": 7,
#     "might": 7,
#     "information": 7,
#     "five": 7,
#     "citizens": 7,
#     "increase": 7,
#     "without": 7,
#     "towards": 7,
#     "israel": 7,
#     "parents": 7,
#     "though": 7,
#     "gun": 7,
#     "show": 7,
#     "each": 7,
#     "among": 7,
#     "much": 7,
#     "died": 7,
#     "washington": 7,
#     "wall": 7,
#     "protesters": 7,
#     "legal": 7,
#     "pro": 7,
#     "failed": 7,
#     "hospital": 7,
#     "union": 7,
#     "2013": 7,
#     "point": 7,
#     "house": 7,
#     "using": 7,
#     "amid": 7,
#     "federal": 7,
#     "weeks": 7,
#     "food": 7,
#     "child": 7,
#     "caption": 7,
#     "condition": 7,
#     "dakota": 7,
#     "pipeline": 7,
#     "away": 6,
#     "documents": 6,
#     "helped": 6,
#     "tried": 6,
#     "regime": 6,
#     "today": 6,
#     "policies": 6,
#     "days": 6,
#     "debate": 6,
#     "shows": 6,
#     "spending": 6,
#     "came": 6,
#     "republican": 6,
#     "smith": 6,
#     "john": 6,
#     "play": 6,
#     "find": 6,
#     "donald": 6,
#     "jail": 6,
#     "'re": 6,
#     "order": 6,
#     "major": 6,
#     "ap": 6,
#     "early": 6,
#     "4": 6,
#     "transport": 6,
#     "late": 6,
#     "black": 6,
#     "press": 6,
#     "areas": 6,
#     "turkish": 6,
#     "trying": 6,
#     "station": 6,
#     "mueller": 6,
#     "earlier": 6,
#     "red": 6,
#     "line": 6,
#     "use": 6,
#     "holding": 6,
#     "iraqi": 6,
#     "roaming": 6,
#     "another": 6,
#     "seeking": 6,
#     "mr.": 6,
#     "himself": 6,
#     "less": 6,
#     "still": 6,
#     "believe": 6,
#     "nation": 6,
#     "became": 6,
#     "jews": 6,
#     "france": 6,
#     "choice": 6,
#     "half": 6,
#     "china": 6,
#     "secret": 6,
#     "arrive": 6,
#     "allegedly": 6,
#     "stabbed": 6,
#     "leave": 6,
#     "syrians": 6,
#     "past": 6,
#     "sanders": 6,
#     "third": 6,
#     "aid": 6,
#     "workers": 6,
#     "reported": 6,
#     "front": 6,
#     "second": 6,
#     "mostly": 6,
#     "true": 6,
#     "wounded": 6,
#     "reporting": 6,
#     "within": 6,
#     "decades": 6,
#     "account": 6,
#     "getty": 6,
#     "images": 6,
#     "russians": 6,
#     "arrived": 6,
#     "question": 6,
#     "nsa": 6,
#     "classified": 6,
#     "party": 6,
#     "election": 6,
#     "claimed": 6,
#     "call": 6,
#     "declared": 6,
#     "see": 6,
#     "four": 6,
#     "percent": 6,
#     "--": 6,
#     "secretary": 6,
#     "result": 6,
#     "emergency": 6,
#     "bombing": 6,
#     "nuclear": 6,
#     "capital": 5,
#     "community": 5,
#     "lives": 5,
#     "tuesday": 5,
#     "assad": 5,
#     "presidential": 5,
#     "poverty": 5,
#     "technology": 5,
#     "event": 5,
#     "campus": 5,
#     "throughout": 5,
#     "15": 5,
#     "outside": 5,
#     "consequences": 5,
#     "same": 5,
#     "incident": 5,
#     "whether": 5,
#     "investigators": 5,
#     "paris": 5,
#     "plane": 5,
#     "clear": 5,
#     "flight": 5,
#     "thursday": 5,
#     "then": 5,
#     "better": 5,
#     "dollars": 5,
#     "remains": 5,
#     "data": 5,
#     "efforts": 5,
#     "recent": 5,
#     "reindeer": 5,
#     "small": 5,
#     "safe": 5,
#     "quickly": 5,
#     "lopez": 5,
#     "sanchez": 5,
#     "rate": 5,
#     "why": 5,
#     "number": 5,
#     "increased": 5,
#     "launched": 5,
#     "gas": 5,
#     "killing": 5,
#     "committed": 5,
#     "price": 5,
#     "militants": 5,
#     "mosul": 5,
#     "destroyed": 5,
#     "orlando": 5,
#     "favor": 5,
#     "deal": 5,
#     "investment": 5,
#     "added": 5,
#     "danger": 5,
#     "convention": 5,
#     "democratic": 5,
#     "prime": 5,
#     "office": 5,
#     "elsewhere": 5,
#     "ever": 5,
#     "korea": 5,
#     "migrate": 5,
#     "apartment": 5,
#     "however": 5,
#     "heart": 5,
#     "despite": 5,
#     "image": 5,
#     "democrats": 5,
#     "center": 5,
#     "officers": 5,
#     "immediately": 5,
#     "act": 5,
#     "truth": 5,
#     "full": 5,
#     "soon": 5,
#     "civil": 5,
#     "rebels": 5,
#     "centers": 5,
#     "apparently": 5,
#     "judge": 5,
#     "asked": 5,
#     "worked": 5,
#     "training": 5,
#     "gave": 5,
#     "egypt": 5,
#     "although": 5,
#     "lead": 5,
#     "until": 5,
#     "others": 5,
#     "actually": 5,
#     "jewish": 5,
#     "taking": 5,
#     "assange": 5,
#     "moment": 5,
#     "politically": 5,
#     "media": 5,
#     "face": 5,
#     "alleged": 5,
#     "generation": 5,
#     "footage": 5,
#     "files": 5,
#     "director": 5,
#     "rubble": 5,
#     "safety": 5,
#     "mccain": 5,
#     "kirkpatrick": 5,
#     "punish": 5,
#     "seen": 5,
#     "cold": 5,
#     "received": 5,
#     "murder": 5,
#     "avoid": 5,
#     "billion": 5,
#     "saudi": 5,
#     "issues": 5,
#     "server": 5,
#     "hanley": 5,
#     "team": 5,
#     "residents": 5,
#     "scene": 5,
#     "un": 5,
#     "hide": 5,
#     "32": 5,
#     "haiti": 5,
#     "girl": 5,
#     "costs": 5,
#     "fans": 5,
#     "once": 4,
#     "reached": 4,
#     "likely": 4,
#     "help": 4,
#     "helping": 4,
#     "took": 4,
#     "led": 4,
#     "fighting": 4,
#     "conflict": 4,
#     "includes": 4,
#     "republicans": 4,
#     "asia": 4,
#     "speech": 4,
#     "george": 4,
#     "toward": 4,
#     "proposed": 4,
#     "feel": 4,
#     "breaking": 4,
#     "behind": 4,
#     "honduras": 4,
#     "nearly": 4,
#     "100": 4,
#     "peace": 4,
#     "institute": 4,
#     "gonz\u00e1lez": 4,
#     "tanks": 4,
#     "problems": 4,
#     "faces": 4,
#     "education": 4,
#     "activists": 4,
#     "something": 4,
#     "months": 4,
#     "personal": 4,
#     "ended": 4,
#     "convicted": 4,
#     "smoke": 4,
#     "airport": 4,
#     "traffic": 4,
#     "5": 4,
#     "underway": 4,
#     "french": 4,
#     "tv": 4,
#     "paper": 4,
#     "moved": 4,
#     "calling": 4,
#     "happen": 4,
#     "cia": 4,
#     "largest": 4,
#     "caucasus": 4,
#     "life": 4,
#     "serious": 4,
#     "metro": 4,
#     "shortly": 4,
#     "illegally": 4,
#     "sanctuary": 4,
#     "rep.": 4,
#     "almost": 4,
#     "hundred": 4,
#     "response": 4,
#     "action": 4,
#     "message": 4,
#     "believed": 4,
#     "dozen": 4,
#     "staff": 4,
#     "particularly": 4,
#     "currently": 4,
#     "hope": 4,
#     "terrorist": 4,
#     "denied": 4,
#     "expert": 4,
#     "monday": 4,
#     "interview": 4,
#     "experience": 4,
#     "west": 4,
#     "network": 4,
#     "claim": 4,
#     "ban": 4,
#     "mateen": 4,
#     "afghanistan": 4,
#     "come": 4,
#     "direct": 4,
#     "calls": 4,
#     "street": 4,
#     "april": 4,
#     "visiting": 4,
#     "leaving": 4,
#     "britain": 4,
#     "warned": 4,
#     "joined": 4,
#     "reach": 4,
#     "vice": 4,
#     "joe": 4,
#     "biden": 4,
#     "similar": 4,
#     "due": 4,
#     "carry": 4,
#     "person": 4,
#     "ministry": 4,
#     "operation": 4,
#     "me": 4,
#     "best": 4,
#     "suspicion": 4,
#     "comments": 4,
#     "expressed": 4,
#     "nominee": 4,
#     "remain": 4,
#     "crimes": 4,
#     "hands": 4,
#     "condemned": 4,
#     "named": 4,
#     "conditions": 4,
#     "vast": 4,
#     "along": 4,
#     "force": 4,
#     "assault": 4,
#     "siege": 4,
#     "significant": 4,
#     "plan": 4,
#     "based": 4,
#     "probably": 4,
#     "service": 4,
#     "october": 4,
#     "additional": 4,
#     "york": 4,
#     "mexican": 4,
#     "school": 4,
#     "assistance": 4,
#     "organization": 4,
#     "shiite": 4,
#     "process": 4,
#     "night": 4,
#     "walking": 4,
#     "western": 4,
#     "carolina": 4,
#     "whistleblower": 4,
#     "start": 4,
#     "japanese": 4,
#     "close": 4,
#     "move": 4,
#     "comes": 4,
#     "leaders": 4,
#     "create": 4,
#     "challenge": 4,
#     "statement": 4,
#     "stone": 4,
#     "activity": 4,
#     "wikileaks": 4,
#     "release": 4,
#     "imprisoned": 4,
#     "returned": 4,
#     "caused": 4,
#     "wife": 4,
#     "top": 4,
#     "final": 4,
#     "enough": 4,
#     "terrorism": 4,
#     "heard": 4,
#     "ran": 4,
#     "hotel": 4,
#     "arrest": 4,
#     "seekers": 4,
#     "migrants": 4,
#     "served": 4,
#     "guilty": 4,
#     "injured": 4,
#     "ally": 4,
#     "town": 4,
#     "airing": 4,
#     "parties": 4,
#     "\u2019ve": 4,
#     "controlled": 4,
#     "shot": 4,
#     "post": 4,
#     "goods": 4,
#     "14": 4,
#     "terror": 4,
#     "islam": 4,
#     "tur": 4,
#     "arabia": 4,
#     "non": 4,
#     "immunity": 4,
#     "river": 4,
#     "january": 4,
#     "contaminated": 4,
#     "fifa": 4,
#     "jebl": 4,
#     "mukaber": 4,
#     "deadly": 4,
#     "arab": 4,
#     "site": 4,
#     "hurricane": 4,
#     "watch": 4,
#     "jeremie": 4,
#     "offences": 4,
#     "san": 4,
#     "imagine": 4,
#     "charge": 4,
#     "company": 4,
#     "teeter": 4,
#     "switch": 4,
#     "eu": 3,
#     "port": 3,
#     "coming": 3,
#     "possible": 3,
#     "hitler": 3,
#     "presence": 3,
#     "argentina": 3,
#     "high": 3,
#     "ranking": 3,
#     "story": 3,
#     "located": 3,
#     "coalition": 3,
#     "eight": 3,
#     "beginning": 3,
#     "granted": 3,
#     "conflicts": 3,
#     "gop": 3,
#     "legislation": 3,
#     "speaking": 3,
#     "talk": 3,
#     "incarcerated": 3,
#     "rally": 3,
#     "republic": 3,
#     "rest": 3,
#     "research": 3,
#     "organized": 3,
#     "needs": 3,
#     "texas": 3,
#     "career": 3,
#     "heights": 3,
#     "paul": 3,
#     "thing": 3,
#     "white": 3,
#     "got": 3,
#     "racism": 3,
#     "either": 3,
#     "aircraft": 3,
#     "list": 3,
#     "questioned": 3,
#     "sea": 3,
#     "never": 3,
#     "siberia": 3,
#     "tens": 3,
#     "increasingly": 3,
#     "indigenous": 3,
#     "allowed": 3,
#     "saturday": 3,
#     "source": 3,
#     "confirmed": 3,
#     "confirmation": 3,
#     "accident": 3,
#     "investigation": 3,
#     "unclear": 3,
#     "spokesman": 3,
#     "professor": 3,
#     "norwegian": 3,
#     "arctic": 3,
#     "finland": 3,
#     "history": 3,
#     "roam": 3,
#     "freely": 3,
#     "argue": 3,
#     "everything": 3,
#     "very": 3,
#     "drive": 3,
#     "operations": 3,
#     "jailed": 3,
#     "leopard": 3,
#     "pounds": 3,
#     "roamed": 3,
#     "appears": 3,
#     "officer": 3,
#     "moving": 3,
#     "advertisement": 3,
#     "critics": 3,
#     "immigrate": 3,
#     "appear": 3,
#     "trip": 3,
#     "attempted": 3,
#     "friendly": 3,
#     "needed": 3,
#     "population": 3,
#     "per": 3,
#     "reason": 3,
#     "development": 3,
#     "economy": 3,
#     "august": 3,
#     "congressional": 3,
#     "plain": 3,
#     "large": 3,
#     "base": 3,
#     "chief": 3,
#     "try": 3,
#     "belgium": 3,
#     "problem": 3,
#     "issue": 3,
#     "groups": 3,
#     "assertion": 3,
#     "ben": 3,
#     "leading": 3,
#     "shooting": 3,
#     "supporter": 3,
#     "pointed": 3,
#     "criminals": 3,
#     "guns": 3,
#     "london": 3,
#     "ii": 3,
#     "vote": 3,
#     "matter": 3,
#     "dangerous": 3,
#     "promise": 3,
#     "voting": 3,
#     "stage": 3,
#     "walked": 3,
#     "voters": 3,
#     "room": 3,
#     "appeal": 3,
#     "class": 3,
#     "aimed": 3,
#     "estimated": 3,
#     "2,000": 3,
#     "discrimination": 3,
#     "signs": 3,
#     "friend": 3,
#     "actively": 3,
#     "sitting": 3,
#     "effect": 3,
#     "friday": 3,
#     "permission": 3,
#     "severed": 3,
#     "bear": 3,
#     "paws": 3,
#     "services": 3,
#     "photographs": 3,
#     "smuggled": 3,
#     "demand": 3,
#     "total": 3,
#     "stay": 3,
#     "beyond": 3,
#     "male": 3,
#     "24": 3,
#     "om": 3,
#     "recently": 3,
#     "welcomed": 3,
#     "bill": 3,
#     "1996": 3,
#     "often": 3,
#     "able": 3,
#     "expected": 3,
#     "culture": 3,
#     "armenian": 3,
#     "cross": 3,
#     "ethnic": 3,
#     "meanwhile": 3,
#     "previous": 3,
#     "running": 3,
#     "movement": 3,
#     "levels": 3,
#     "stand": 3,
#     "damage": 3,
#     "giving": 3,
#     "role": 3,
#     "ceasefire": 3,
#     "district": 3,
#     "agreement": 3,
#     "governor": 3,
#     "higher": 3,
#     "yesterday": 3,
#     "six": 3,
#     "yet": 3,
#     "legally": 3,
#     "curiel": 3,
#     "previously": 3,
#     "means": 3,
#     "cnn": 3,
#     "building": 3,
#     "fight": 3,
#     "afghan": 3,
#     "citizen": 3,
#     "member": 3,
#     "society": 3,
#     "villages": 3,
#     "18": 3,
#     "enforcement": 3,
#     "mother": 3,
#     "baby": 3,
#     "remember": 3,
#     "body": 3,
#     "@": 3,
#     "bomb": 3,
#     "win": 3,
#     "contractor": 3,
#     "nothing": 3,
#     "elections": 3,
#     "shoot": 3,
#     "risks": 3,
#     "december": 3,
#     "africa": 3,
#     "protect": 3,
#     "chairman": 3,
#     "steps": 3,
#     "ongoing": 3,
#     "unloading": 3,
#     "connection": 3,
#     "2009": 3,
#     "troops": 3,
#     "defend": 3,
#     "showing": 3,
#     "kids": 3,
#     "course": 3,
#     "direction": 3,
#     "bannon": 3,
#     "conspiracy": 3,
#     "immigrating": 3,
#     "semitic": 3,
#     "followed": 3,
#     "minority": 3,
#     "politicians": 3,
#     "leader": 3,
#     "suspect": 3,
#     "believes": 3,
#     "individual": 3,
#     "must": 3,
#     "employees": 3,
#     "hong": 3,
#     "kong": 3,
#     "raised": 3,
#     "violent": 3,
#     "longtime": 3,
#     "regular": 3,
#     "embassy": 3,
#     "peaceful": 3,
#     "sheriff": 3,
#     "clark": 3,
#     "gone": 3,
#     "fought": 3,
#     "kurdish": 3,
#     "2011": 3,
#     "ballots": 3,
#     "walks": 3,
#     "polling": 3,
#     "majority": 3,
#     "described": 3,
#     "job": 3,
#     "deportation": 3,
#     "coup": 3,
#     "stumbled": 3,
#     "defense": 3,
#     "markets": 3,
#     "nations": 3,
#     "barack": 3,
#     "proposal": 3,
#     "denies": 3,
#     "encel": 3,
#     "business": 3,
#     "november": 3,
#     "production": 3,
#     "radical": 3,
#     "correct": 3,
#     "certain": 3,
#     "responsible": 3,
#     "diplomatic": 3,
#     "laptop": 3,
#     "missing": 3,
#     "showed": 3,
#     "headquarters": 3,
#     "senior": 3,
#     "went": 3,
#     "related": 3,
#     "neighborhood": 3,
#     "rosenfeld": 3,
#     "involved": 3,
#     "stable": 3,
#     "closely": 3,
#     "communities": 3,
#     "!": 3,
#     "access": 3,
#     "fallen": 3,
#     "spent": 3,
#     "dieu": 3,
#     "nalio": 3,
#     "chery": 3,
#     "debris": 3,
#     "makes": 3,
#     "buildings": 3,
#     "thought": 3,
#     "records": 3,
#     "meant": 3,
#     "400": 3,
#     "kind": 3,
#     "rather": 3,
#     "wake": 3,
#     "anthrax": 3,
#     "seek": 3,
#     "erna": 3,
#     "solberg": 3,
#     "daughter": 3,
#     "briefly": 3,
#     "engage": 3,
#     "icann": 3,
#     "key": 3,
#     "understand": 3,
#     "dismissed": 3,
#     "change": 3,
#     "largely": 3,
#     "comstock": 3,
#     "virginia": 3,
#     "congress": 3,
#     "shipment": 3,
#     "further": 3,
#     "petraeus": 3,
#     "private": 3,
#     "exactly": 3,
#     "videos": 3,
#     "encouraging": 3,
#     "francisco": 3,
#     "england": 3,
#     "commission": 3,
#     "goal": 3,
#     "self": 3,
#     "sophisticated": 3,
#     "nanny": 3,
#     "wuhayeb": 3,
#     "trillion": 3,
#     "disarmament": 3,
#     "km": 2,
#     "houses": 2,
#     "ice": 2,
#     "light": 2,
#     "aware": 2,
#     "capture": 2,
#     "bombed": 2,
#     "strikes": 2,
#     "viewed": 2,
#     "w.": 2,
#     "bush": 2,
#     "chose": 2,
#     "program": 2,
#     "rhetoric": 2,
#     "traditional": 2,
#     "counts": 2,
#     "widely": 2,
#     "commentators": 2,
#     "dictators": 2,
#     "authoritarian": 2,
#     "regimes": 2,
#     "opponents": 2,
#     "earth": 2,
#     "desperation": 2,
#     "turmoil": 2,
#     "nicaragua": 2,
#     "trails": 2,
#     "neighbors": 2,
#     "triangle": 2,
#     "guatemala": 2,
#     "el": 2,
#     "salvador": 2,
#     "dominican": 2,
#     "outspent": 2,
#     "isthmus": 2,
#     "stockholm": 2,
#     "costa": 2,
#     "rica": 2,
#     "manuel": 2,
#     "ill": 2,
#     "suited": 2,
#     "combat": 2,
#     "healthcare": 2,
#     "infrastructure": 2,
#     "comment": 2,
#     "sit": 2,
#     "entirely": 2,
#     "covered": 2,
#     "things": 2,
#     "recalled": 2,
#     "morning": 2,
#     "indiana": 2,
#     "unloaded": 2,
#     "false": 2,
#     "father": 2,
#     "looked": 2,
#     "blow": 2,
#     "neck": 2,
#     "admitted": 2,
#     "personally": 2,
#     "targets": 2,
#     "angry": 2,
#     "ilona": 2,
#     "bogen": 2,
#     "lithuania": 2,
#     "mayfield": 2,
#     "items": 2,
#     "controversy": 2,
#     "african": 2,
#     "offenses": 2,
#     "fact": 2,
#     "charged": 2,
#     "'ve": 2,
#     "airbus": 2,
#     "crew": 2,
#     "de": 2,
#     "nighttime": 2,
#     "suddenly": 2,
#     "plummeted": 2,
#     "available": 2,
#     "pilot": 2,
#     "controllers": 2,
#     "switzerland": 2,
#     "padova": 2,
#     "0": 2,
#     "2": 2,
#     "8": 2,
#     "becomes": 2,
#     "affordable": 2,
#     "remote": 2,
#     "mammoth": 2,
#     "secrets": 2,
#     "boxes": 2,
#     "approximately": 2,
#     "mediterranean": 2,
#     "crash": 2,
#     "board": 2,
#     "egyptian": 2,
#     "minutes": 2,
#     "minor": 2,
#     "page": 2,
#     "harsson": 2,
#     "son": 2,
#     "books": 2,
#     "positive": 2,
#     "neither": 2,
#     "afternoon": 2,
#     "\u2018": 2,
#     "special": 2,
#     "fired": 2,
#     "species": 2,
#     "persian": 2,
#     "200": 2,
#     "typically": 2,
#     "19th": 2,
#     "century": 2,
#     "asking": 2,
#     "offered": 2,
#     "centre": 2,
#     "keep": 2,
#     "blast": 2,
#     "rush": 2,
#     "hour": 2,
#     "deported": 2,
#     "laws": 2,
#     "refuge": 2,
#     "trey": 2,
#     "gowdy": 2,
#     "disclosed": 2,
#     "worse": 2,
#     "r": 2,
#     "highest": 2,
#     "bolster": 2,
#     "itself": 2,
#     "sought": 2,
#     "cent": 2,
#     "tend": 2,
#     "larger": 2,
#     "secular": 2,
#     "influx": 2,
#     "market": 2,
#     "independent": 2,
#     "german": 2,
#     "hours": 2,
#     "rockets": 2,
#     "carrying": 2,
#     "sarin": 2,
#     "damascus": 2,
#     "chemical": 2,
#     "decided": 2,
#     "send": 2,
#     "sight": 2,
#     "prisoners": 2,
#     "mezzeh": 2,
#     "detainees": 2,
#     "target": 2,
#     "surveillance": 2,
#     "gerasimov": 2,
#     "isil": 2,
#     "partners": 2,
#     "employee": 2,
#     "semitism": 2,
#     "palestinian": 2,
#     "radio": 2,
#     "gurion": 2,
#     "bank": 2,
#     "49": 2,
#     "lgbt": 2,
#     "muslims": 2,
#     "entering": 2,
#     "killer": 2,
#     "bottom": 2,
#     "phone": 2,
#     "gangs": 2,
#     "cases": 2,
#     "celebrating": 2,
#     "birthday": 2,
#     "risked": 2,
#     "brexit": 2,
#     "engagement": 2,
#     "pacific": 2,
#     "finds": 2,
#     "presidency": 2,
#     "terms": 2,
#     "losing": 2,
#     "sides": 2,
#     "idea": 2,
#     "\u2019m": 2,
#     "scared": 2,
#     "great": 2,
#     "urged": 2,
#     "arms": 2,
#     "wrapped": 2,
#     "began": 2,
#     "establishment": 2,
#     "demonstrators": 2,
#     "ethiopia": 2,
#     "cheol": 2,
#     "resident": 2,
#     "waiting": 2,
#     "20": 2,
#     "simply": 2,
#     "plans": 2,
#     "schools": 2,
#     "student": 2,
#     "chicago": 2,
#     "declining": 2,
#     "concealed": 2,
#     "students": 2,
#     "expression": 2,
#     "latest": 2,
#     "universities": 2,
#     "license": 2,
#     "bring": 2,
#     "ties": 2,
#     "80": 2,
#     "miles": 2,
#     "coast": 2,
#     "korean": 2,
#     "discovered": 2,
#     "smuggling": 2,
#     "customs": 2,
#     "considered": 2,
#     "restaurants": 2,
#     "difficult": 2,
#     "planning": 2,
#     "box": 2,
#     "sits": 2,
#     "twenty": 2,
#     "breton": 2,
#     "island": 2,
#     "canada": 2,
#     "housing": 2,
#     "carbon": 2,
#     "choose": 2,
#     "citizenship": 2,
#     "low": 2,
#     "100,000": 2,
#     "sister": 2,
#     "drugs": 2,
#     "stefania": 2,
#     "dubrovina": 2,
#     "eyes": 2,
#     "hacked": 2,
#     "owned": 2,
#     "petersburg": 2,
#     "february": 2,
#     "intensified": 2,
#     "lately": 2,
#     "temporary": 2,
#     "roadblocks": 2,
#     "confiscate": 2,
#     "mohammad": 2,
#     "shown": 2,
#     "causing": 2,
#     "governments": 2,
#     "christians": 2,
#     "managed": 2,
#     "effort": 2,
#     "husband": 2,
#     "voted": 2,
#     "remind": 2,
#     "streets": 2,
#     "senator": 2,
#     "proof": 2,
#     "hate": 2,
#     "hostility": 2,
#     "produce": 2,
#     "outcomes": 2,
#     "genocide": 2,
#     "greece": 2,
#     "armenians": 2,
#     "marched": 2,
#     "nagorno": 2,
#     "karabakh": 2,
#     "waving": 2,
#     "flags": 2,
#     "tehran": 2,
#     "st.": 2,
#     "ankara": 2,
#     "hostilities": 2,
#     "recognizes": 2,
#     "rt": 2,
#     "deployed": 2,
#     "positioned": 2,
#     "plunge": 2,
#     "degree": 2,
#     "function": 2,
#     "kept": 2,
#     "flat": 2,
#     "inspect": 2,
#     "neighbourhood": 2,
#     "playing": 2,
#     "talks": 2,
#     "negotiated": 2,
#     "outset": 2,
#     "homs": 2,
#     "amount": 2,
#     "oppose": 2,
#     "figures": 2,
#     "health": 2,
#     "spokeswoman": 2,
#     "chaib": 2,
#     "partially": 2,
#     "hospitals": 2,
#     "care": 2,
#     "hopes": 2,
#     "u.n.": 2,
#     "schengen": 2,
#     "give": 2,
#     "e.u.": 2,
#     "controls": 2,
#     "masses": 2,
#     "lawsuits": 2,
#     "mexico": 2,
#     "stated": 2,
#     "rule": 2,
#     "tapper": 2,
#     "racist": 2,
#     "responded": 2,
#     "pressed": 2,
#     "rural": 2,
#     "forced": 2,
#     "pakistan": 2,
#     "doctors": 2,
#     "social": 2,
#     "fuaa": 2,
#     "kafraya": 2,
#     "jibrin": 2,
#     "outskirts": 2,
#     "dec.": 2,
#     "ourfalian": 2,
#     "cologne": 2,
#     "kilometers": 2,
#     "beating": 2,
#     "wo": 2,
#     "injuries": 2,
#     "migrant": 2,
#     "upper": 2,
#     "ca": 2,
#     "mind": 2,
#     "islamist": 2,
#     "industry": 2,
#     "waging": 2,
#     "insurgency": 2,
#     "parts": 2,
#     "formal": 2,
#     "writing": 2,
#     "reference": 2,
#     "controversial": 2,
#     "global": 2,
#     "violating": 2,
#     "lawyer": 2,
#     "candidate": 2,
#     "2008": 2,
#     "cancel": 2,
#     "somali": 2,
#     "represented": 2,
#     "perhaps": 2,
#     "japan": 2,
#     "firms": 2,
#     "edge": 2,
#     "improve": 2,
#     "cities": 2,
#     "sources": 2,
#     "package": 2,
#     "vladimir": 2,
#     "may.": 2,
#     "progress": 2,
#     "hold": 2,
#     "religious": 2,
#     "continues": 2,
#     "poses": 2,
#     "interests": 2,
#     "sub": 2,
#     "committee": 2,
#     "overseas": 2,
#     "roger": 2,
#     "fully": 2,
#     "explain": 2,
#     "communication": 2,
#     "referring": 2,
#     "julian": 2,
#     "ukrainians": 2,
#     "issued": 2,
#     "deliver": 2,
#     "demanded": 2,
#     "abandoned": 2,
#     "reality": 2,
#     "mexicans": 2,
#     "flood": 2,
#     "lies": 2,
#     "daily": 2,
#     "spring": 2,
#     "dozens": 2,
#     "shots": 2,
#     "suggest": 2,
#     "zealand": 2,
#     "debates": 2,
#     "wearing": 2,
#     "cancer": 2,
#     "purge": 2,
#     "infamous": 2,
#     "higgins": 2,
#     "10,000": 2,
#     "emigrated": 2,
#     "record": 2,
#     "single": 2,
#     "%": 2,
#     "rising": 2,
#     "crimea": 2,
#     "soviet": 2,
#     "worshipers": 2,
#     "mosque": 2,
#     "volunteers": 2,
#     "minuscule": 2,
#     "radicalization": 2,
#     "active": 2,
#     "outlets": 2,
#     "latvia": 2,
#     "various": 2,
#     "theories": 2,
#     "example": 2,
#     "anything": 2,
#     "strong": 2,
#     "mayor": 2,
#     "czech": 2,
#     "announcement": 2,
#     "reasons": 2,
#     "personnel": 2,
#     "widespread": 2,
#     "sex": 2,
#     "justify": 2,
#     "poland": 2,
#     "distributing": 2,
#     "prevent": 2,
#     "brussels": 2,
#     "elite": 2,
#     "hearing": 2,
#     "accused": 2,
#     "radicalized": 2,
#     "themselves": 2,
#     "becoming": 2,
#     "sparked": 2,
#     "ostend": 2,
#     "thrown": 2,
#     "rapists": 2,
#     "photo": 2,
#     "forth": 2,
#     "seemingly": 2,
#     "deeply": 2,
#     "extent": 2,
#     "concerns": 2,
#     "riot": 2,
#     "policemen": 2,
#     "assembly": 2,
#     "wing": 2,
#     "demanding": 2,
#     "duterte": 2,
#     "breaks": 2,
#     "water": 2,
#     "35": 2,
#     "interest": 2,
#     "sen.": 2,
#     "featuring": 2,
#     "put": 2,
#     "gathered": 2,
#     "felt": 2,
#     "situation": 2,
#     "defending": 2,
#     "biter": 2,
#     "newly": 2,
#     "introduced": 2,
#     "tool": 2,
#     "pieces": 2,
#     "fatima": 2,
#     "name": 2,
#     "finally": 2,
#     "escaped": 2,
#     "compared": 2,
#     "reaching": 2,
#     "camp": 2,
#     "cast": 2,
#     "seize": 2,
#     "worst": 2,
#     "cadets": 2,
#     "parliamentary": 2,
#     "francis": 2,
#     "palm": 2,
#     "jesus": 2,
#     "july": 2,
#     "drop": 2,
#     "please": 2,
#     "barbarians": 2,
#     "continue": 2,
#     "villagers": 2,
#     "retreat": 2,
#     "walk": 2,
#     "refused": 2,
#     "wage": 2,
#     "supported": 2,
#     "agenda": 2,
#     "worldwide": 2,
#     "800": 2,
#     "militarily": 2,
#     "barriers": 2,
#     "empire": 2,
#     "sort": 2,
#     "goes": 2,
#     "quite": 2,
#     "power": 2,
#     "ending": 2,
#     "trouble": 2,
#     "resistance": 2,
#     "claims": 2,
#     "aim": 2,
#     "humanitarian": 2,
#     "wanted": 2,
#     "copyright": 2,
#     "yerofeyev": 2,
#     "alexandrov": 2,
#     "soldiers": 2,
#     "turned": 2,
#     "kinds": 2,
#     "daesh": 2,
#     "earned": 2,
#     "frequently": 2,
#     "contain": 2,
#     "feeling": 2,
#     "lot": 2,
#     "23": 2,
#     "supports": 2,
#     "katy": 2,
#     "hackers": 2,
#     "trail": 2,
#     "employed": 2,
#     "mrs.": 2,
#     "pagliano": 2,
#     "secure": 2,
#     "prosecution": 2,
#     "liberties": 2,
#     "imposed": 2,
#     "sees": 2,
#     "judges": 2,
#     "seeing": 2,
#     "sweden": 2,
#     "2010": 2,
#     "cables": 2,
#     "swedish": 2,
#     "warrant": 2,
#     "lived": 2,
#     "june": 2,
#     "british": 2,
#     "insisted": 2,
#     "macbook": 2,
#     "platte": 2,
#     "existing": 2,
#     "current": 2,
#     "aide": 2,
#     "contacted": 2,
#     "assistant": 2,
#     "entire": 2,
#     "review": 2,
#     "experts": 2,
#     "potential": 2,
#     "exposure": 2,
#     "fukushima": 2,
#     "slight": 2,
#     "limited": 2,
#     "iodine": 2,
#     "eating": 2,
#     "25": 2,
#     "extension": 2,
#     "pkk": 2,
#     "decade": 2,
#     "shelling": 2,
#     "threat": 2,
#     "azaz": 2,
#     "ypg": 2,
#     "tel": 2,
#     "adjacent": 2,
#     "david": 2,
#     "gulf": 2,
#     "provide": 2,
#     "significantly": 2,
#     "share": 2,
#     "\u201cpolice": 2,
#     "units": 2,
#     "rushed": 2,
#     "shaare": 2,
#     "zedek": 2,
#     "suspects": 2,
#     "assailants": 2,
#     "search": 2,
#     "ruvio": 2,
#     "surgery": 2,
#     "chance": 2,
#     "armon": 2,
#     "talpiot": 2,
#     "concrete": 2,
#     "30": 2,
#     "kwan": 2,
#     "corner": 2,
#     "every": 2,
#     "grandparents": 2,
#     "ability": 2,
#     "dream": 2,
#     "cannon": 2,
#     "ball": 2,
#     "26": 2,
#     "sacred": 2,
#     "burial": 2,
#     "28": 2,
#     "protest": 2,
#     "29": 2,
#     "cleveland": 2,
#     "pretty": 2,
#     "soldier": 2,
#     "suggested": 2,
#     "10": 2,
#     "winners": 2,
#     "imprison": 2,
#     "winds": 2,
#     "matthew": 2,
#     "side": 2,
#     "petit": 2,
#     "goave": 2,
#     "bridge": 2,
#     "woman": 2,
#     "dropped": 2,
#     "consider": 2,
#     "destroy": 2,
#     "directly": 2,
#     "backing": 2,
#     "possibility": 2,
#     "sooner": 2,
#     "inspector": 2,
#     "doing": 2,
#     "scale": 2,
#     "garcia": 2,
#     "car": 2,
#     "blown": 2,
#     "damaged": 2,
#     "critical": 2,
#     "nice": 2,
#     "massacre": 2,
#     "absolutely": 2,
#     "uk": 2,
#     "pornography": 2,
#     "parliament": 2,
#     "follow": 2,
#     "fast": 2,
#     "routinely": 2,
#     "inherently": 2,
#     "protesting": 2,
#     "form": 2,
#     "blame": 2,
#     "acts": 2,
#     "california": 2,
#     "adviser": 2,
#     "leibenluft": 2,
#     "focused": 2,
#     "heavily": 2,
#     "capitol": 2,
#     "autonomous": 2,
#     "yamalo": 2,
#     "dmitry": 2,
#     "kobylkin": 2,
#     "infection": 2,
#     "quarantine": 2,
#     "break": 2,
#     "therefore": 2,
#     "otherwise": 2,
#     "flow": 2,
#     "berlingske": 2,
#     "meet": 2,
#     "chavez": 2,
#     "handful": 2,
#     "fellow": 2,
#     "hostages": 2,
#     "inside": 2,
#     "yazidi": 2,
#     "freed": 2,
#     "cell": 2,
#     "argued": 2,
#     "deem": 2,
#     "blasphemy": 2,
#     "incarcerate": 2,
#     "dissent": 2,
#     "escapes": 2,
#     "authority": 2,
#     "worry": 2,
#     "protecting": 2,
#     "fears": 2,
#     "scores": 2,
#     "important": 2,
#     "putting": 2,
#     "transition": 2,
#     "unrealistic": 2,
#     "mark": 2,
#     "nolan": 2,
#     "resort": 2,
#     "hurghada": 2,
#     "beach": 2,
#     "anger": 2,
#     "openly": 2,
#     "correctness": 2,
#     "wrong": 2,
#     "disheartening": 2,
#     "opportunity": 2,
#     "include": 2,
#     "jordan": 2,
#     "45,000": 2,
#     "migrating": 2,
#     "television": 2,
#     "spot": 2,
#     "caity": 2,
#     "hard": 2,
#     "advantage": 2,
#     "watched": 2,
#     "fan": 2,
#     "spoke": 2,
#     "anonymity": 2,
#     "capabilities": 2,
#     "level": 2,
#     "council": 2,
#     "sale": 2,
#     "fine": 2,
#     "english": 2,
#     "kyrgyz": 2,
#     "bishkek": 2,
#     "armed": 2,
#     "attempt": 2,
#     "prisons": 2,
#     "transferred": 2,
#     "southern": 2,
#     "positions": 2,
#     "mcgraw": 2,
#     "seats": 2,
#     "questions": 2,
#     "vowing": 2,
#     "fees": 2,
#     "\u2019d": 2,
#     "stade": 2,
#     "v\u00e9lodrome": 2,
#     "stewards": 2,
#     "hooligans": 2,
#     "together": 2,
#     "stands": 2,
#     "bodies": 2,
#     "yukos": 2,
#     "kukes": 2,
#     "producing": 2,
#     "outbreak": 2,
#     "performance": 2,
#     "serve": 2,
#     "cars": 2,
#     "bombs": 2,
#     "drivers": 2,
#     "jihadists": 2,
#     "fsa": 2,
#     "sky": 2,
#     "gold": 2,
#     "satellite": 2,
#     "imagery": 2,
#     "location": 2,
#     "collection": 2,
#     "grab": 2,
#     "whole": 2,
#     "abroad": 2,
#     "convoy": 2,
#     "fire": 2,
#     "sunni": 2,
#     "lifted": 2,
#     "campbell": 2,
#     "falls": 2,
#     "acknowledge": 2,
#     "budget": 2,
#     "\u2019re": 2,
#     "write": 2,
#     "words": 2,
#     "encryption": 2,
#     "encrypted": 2,
#     "irna": 2,
#     "javadi": 2,
#     "landed": 2,
#     "initially": 2,
#     "contained": 2,
#     "jeffrey": 2,
#     "sterling": 2,
#     "code": 2,
#     "codes": 2,
#     "check": 2,
#     "darayya": 2,
#     "corruption": 2,
#     "define": 2,
#     "tajiks": 2,
#     "prussia": 1,
#     "annexed": 1,
#     "wwii": 1,
#     "germans": 1,
#     "expelled": 1,
#     "300": 1,
#     "baltic": 1,
#     "fleet": 1,
#     "prove": 1,
#     "cover": 1,
#     "oss": 1,
#     "nazi": 1,
#     "punishment": 1,
#     "adolf": 1,
#     "eichmann": 1,
#     "1960": 1,
#     "85": 1,
#     "happened": 1,
#     "mistaken": 1,
#     "varying": 1,
#     "deadliest": 1,
#     "perpetrated": 1,
#     "ronald": 1,
#     "reagan": 1,
#     "icon": 1,
#     "famously": 1,
#     "southeast": 1,
#     "invoked": 1,
#     "generous": 1,
#     "1989": 1,
#     "farewell": 1,
#     "ignited": 1,
#     "restart": 1,
#     "resettlement": 1,
#     "9/11": 1,
#     "advocating": 1,
#     "historically": 1,
#     "presidents": 1,
#     "welcoming": 1,
#     "quigley": 1,
#     "easier": 1,
#     "h.r.": 1,
#     "4731": 1,
#     "silencing": 1,
#     "uncomfortable": 1,
#     "cherrypick": 1,
#     "tag": 1,
#     "criticised": 1,
#     "remarks": 1,
#     "evocative": 1,
#     "tinpot": 1,
#     "pueblo": 1,
#     "colorado": 1,
#     "assailed": 1,
#     "scorched": 1,
#     "strategy": 1,
#     "sign": 1,
#     "desperate": 1,
#     "wednesday": 1,
#     "supportive": 1,
#     "tribune": 1,
#     "different": 1,
#     "harshest": 1,
#     "primary": 1,
#     "culminating": 1,
#     "accusation": 1,
#     "linked": 1,
#     "f.": 1,
#     "kennedy": 1,
#     "assassin": 1,
#     "struggled": 1,
#     "ohio": 1,
#     "pop": 1,
#     "songs": 1,
#     "background": 1,
#     "browse": 1,
#     "deli": 1,
#     "rarely": 1,
#     "candies": 1,
#     "dried": 1,
#     "salted": 1,
#     "fish": 1,
#     "perogies": 1,
#     "heaps": 1,
#     "imported": 1,
#     "sausage": 1,
#     "pick": 1,
#     "language": 1,
#     "newspapers": 1,
#     "prominently": 1,
#     "feature": 1,
#     "coverage": 1,
#     "manafort": 1,
#     "manager": 1,
#     "consulting": 1,
#     "stirred": 1,
#     "unintended": 1,
#     "latino": 1,
#     "nonviolent": 1,
#     "address": 1,
#     "systemic": 1,
#     "leads": 1,
#     "contributor": 1,
#     "destroying": 1,
#     "equipment": 1,
#     "suffocating": 1,
#     "pilots": 1,
#     "looking": 1,
#     "clues": 1,
#     "a320": 1,
#     "poring": 1,
#     "passenger": 1,
#     "charles": 1,
#     "gaulle": 1,
#     "cruising": 1,
#     "normally": 1,
#     "skies": 1,
#     "cairo": 1,
#     "lurched": 1,
#     "spun": 1,
#     "38,000": 1,
#     "feet": 1,
#     "issuing": 1,
#     "distress": 1,
#     "signal": 1,
#     "audio": 1,
#     "doomed": 1,
#     "indicates": 1,
#     "routine": 1,
#     "checked": 1,
#     "zurich": 1,
#     "midnight": 1,
#     "handed": 1,
#     "italian": 1,
#     "padua": 1,
#     "7": 1,
#     "unintelligible": 1,
#     "zero": 1,
#     "degrees": 1,
#     "celsius": 1,
#     "locals": 1,
#     "embarking": 1,
#     "expeditions": 1,
#     "corners": 1,
#     "precious": 1,
#     "lucrative": 1,
#     "tusks": 1,
#     "sell": 1,
#     "prized": 1,
#     "carvers": 1,
#     "bans": 1,
#     "elephant": 1,
#     "ivory": 1,
#     "tribes": 1,
#     "hunt": 1,
#     "ancient": 1,
#     "ancestral": 1,
#     "lands": 1,
#     "locked": 1,
#     "permafrost": 1,
#     "revealing": 1,
#     "fyodorov": 1,
#     "cbs": 1,
#     "recorders": 1,
#     "commonly": 1,
#     "pings": 1,
#     "recovery": 1,
#     "egyptair": 1,
#     "confirm": 1,
#     "deny": 1,
#     "williams": 1,
#     "detected": 1,
#     "places": 1,
#     "moments": 1,
#     "cause": 1,
#     "66": 1,
#     "handout": 1,
#     "via": 1,
#     "sebastien": 1,
#     "barthe": 1,
#     "associated": 1,
#     "automatic": 1,
#     "detection": 1,
#     "messages": 1,
#     "indicating": 1,
#     "disappeared": 1,
#     "radar": 1,
#     "flying": 1,
#     "\u00f8yvind": 1,
#     "ravna": 1,
#     "constitution": 1,
#     "apply": 1,
#     "adjustments": 1,
#     "pointing": 1,
#     "reflect": 1,
#     "changes": 1,
#     "riverbeds": 1,
#     "shifting": 1,
#     "position": 1,
#     "sandbanks": 1,
#     "islets": 1,
#     "facebook": 1,
#     "halti": 1,
#     "anniversary": 1,
#     "gift": 1,
#     "centenary": 1,
#     "rewrite": 1,
#     "geography": 1,
#     "garnered": 1,
#     "14,000": 1,
#     "likes": 1,
#     "reaction": 1,
#     "overwhelmingly": 1,
#     "objection": 1,
#     "sami": 1,
#     "belong": 1,
#     "knows": 1,
#     "nrk": 1,
#     "dark": 1,
#     "occasional": 1,
#     "trucks": 1,
#     "transporting": 1,
#     "o'clock": 1,
#     "eyewash": 1,
#     "deceives": 1,
#     "workforce": 1,
#     "advise": 1,
#     "leak": 1,
#     "hang": 1,
#     "grow": 1,
#     "paw": 1,
#     "print": 1,
#     "size": 1,
#     "fearsome": 1,
#     "predator": 1,
#     "hunts": 1,
#     "deer": 1,
#     "wild": 1,
#     "pig": 1,
#     "hare": 1,
#     "mammals": 1,
#     "prey": 1,
#     "snap": 1,
#     "jaws": 1,
#     "mountains": 1,
#     "caspian": 1,
#     "seas": 1,
#     "mtsyri": 1,
#     "novice": 1,
#     "famous": 1,
#     "poem": 1,
#     "written": 1,
#     "1839": 1,
#     "romantic": 1,
#     "writer": 1,
#     "mikhail": 1,
#     "lermontov": 1,
#     "eponymous": 1,
#     "hero": 1,
#     "battles": 1,
#     "tourists": 1,
#     "reopen": 1,
#     "confused": 1,
#     "telling": 1,
#     "reception": 1,
#     "repeatedly": 1,
#     "shouted": 1,
#     "carnage": 1,
#     "occurred": 1,
#     "08:00": 1,
#     "gmt": 1,
#     "maelbeek": 1,
#     "felony": 1,
#     "convictions": 1,
#     "encourage": 1,
#     "expense": 1,
#     "gowdyhouse": 1,
#     "dems": 1,
#     "flynn": 1,
#     "chaffetz": 1,
#     "transparency": 1,
#     "quintessential": 1,
#     "straight": 1,
#     "arrow": 1,
#     "s.c.": 1,
#     "1982": 1,
#     "1.51": 1,
#     "birthrate": 1,
#     "introducing": 1,
#     "short": 1,
#     "2.0": 1,
#     "ensure": 1,
#     "replenishes": 1,
#     "900,000": 1,
#     "70": 1,
#     "average": 1,
#     "stephan": 1,
#     "sievert": 1,
#     "migration": 1,
#     "labour": 1,
#     "berlin": 1,
#     "promising": 1,
#     "21st": 1,
#     "densely": 1,
#     "populated": 1,
#     "neighborhoods": 1,
#     "fourteen": 1,
#     "announced": 1,
#     "wait": 1,
#     "approval": 1,
#     "continued": 1,
#     "dictator": 1,
#     "hamada": 1,
#     "transported": 1,
#     "explanation": 1,
#     "agents": 1,
#     "empty": 1,
#     "hangar": 1,
#     "logical": 1,
#     "drones": 1,
#     "vicinity": 1,
#     "valery": 1,
#     "concerned": 1,
#     "scenario": 1,
#     "formerly": 1,
#     "passage": 1,
#     "realize": 1,
#     "bands": 1,
#     "chased": 1,
#     "belgian": 1,
#     "funded": 1,
#     "charity": 1,
#     "entry": 1,
#     "inflating": 1,
#     "distract": 1,
#     "brigitte": 1,
#     "herremans": 1,
#     "works": 1,
#     "catholic": 1,
#     "pax": 1,
#     "christi": 1,
#     "broederlijk": 1,
#     "delen": 1,
#     "aug.": 1,
#     "9": 1,
#     "relevant": 1,
#     "professional": 1,
#     "nightclub": 1,
#     "massacres": 1,
#     "omar": 1,
#     "unites": 1,
#     "link": 1,
#     "pledged": 1,
#     "allegiance": 1,
#     "leadership": 1,
#     "911": 1,
#     "spree": 1,
#     "cameron": 1,
#     "90th": 1,
#     "queen": 1,
#     "elizabeth": 1,
#     "windsor": 1,
#     "castle": 1,
#     "implored": 1,
#     "britons": 1,
#     "queue": 1,
#     "negotiating": 1,
#     "deals": 1,
#     "runs": 1,
#     "counter": 1,
#     "vision": 1,
#     "interconnected": 1,
#     "societies": 1,
#     "illustrates": 1,
#     "frustrating": 1,
#     "cycle": 1,
#     "pull": 1,
#     "confronting": 1,
#     "fueled": 1,
#     "attempting": 1,
#     "practical": 1,
#     "divorce": 1,
#     "consume": 1,
#     "valuable": 1,
#     "trading": 1,
#     "reliable": 1,
#     "dealing": 1,
#     "ambitious": 1,
#     "transatlantic": 1,
#     "partnership": 1,
#     "momentum": 1,
#     "growing": 1,
#     "sentiment": 1,
#     "38-year": 1,
#     "nurse": 1,
#     "currying": 1,
#     "delegates": 1,
#     "audience": 1,
#     "someone": 1,
#     "dubbed": 1,
#     "grown": 1,
#     "demagogue": 1,
#     "departing": 1,
#     "surprise": 1,
#     "appearance": 1,
#     "electrified": 1,
#     "seems": 1,
#     "ready": 1,
#     "embrace": 1,
#     "biggest": 1,
#     "cheer": 1,
#     "philadelphia": 1,
#     "evening": 1,
#     "raw": 1,
#     "emotion": 1,
#     "touched": 1,
#     "sandy": 1,
#     "hook": 1,
#     "overt": 1,
#     "mission": 1,
#     "succession": 1,
#     "big": 1,
#     "names": 1,
#     "tempted": 1,
#     "struggling": 1,
#     "mood": 1,
#     "stole": 1,
#     "blunt": 1,
#     "retort": 1,
#     "organisers": 1,
#     "benjamin": 1,
#     "netanyahu": 1,
#     "suffering": 1,
#     "chanted": 1,
#     "slogans": 1,
#     "pictures": 1,
#     "relatives": 1,
#     "antaihe": 1,
#     "30-year": 1,
#     "brother": 1,
#     "ashebo": 1,
#     "noted": 1,
#     "encourages": 1,
#     "detailing": 1,
#     "austin": 1,
#     "nora": 1,
#     "dolliver": 1,
#     "graduate": 1,
#     "narrowed": 1,
#     "languages": 1,
#     "subject": 1,
#     "offer": 1,
#     "admission": 1,
#     "guidelines": 1,
#     "pursue": 1,
#     "dual": 1,
#     "masters": 1,
#     "studies": 1,
#     "library": 1,
#     "sciences": 1,
#     "someplace": 1,
#     "confident": 1,
#     "packing": 1,
#     "pistol": 1,
#     "academics": 1,
#     "chilling": 1,
#     "pass": 1,
#     "compels": 1,
#     "holders": 1,
#     "aged": 1,
#     "21": 1,
#     "handguns": 1,
#     "relatively": 1,
#     "yacht": 1,
#     "elfin": 1,
#     "busan": 1,
#     "vladivostok": 1,
#     "130": 1,
#     "vessel": 1,
#     "kimchaek": 1,
#     "consul": 1,
#     "visit": 1,
#     "splayed": 1,
#     "gruesome": 1,
#     "picture": 1,
#     "tonne": 1,
#     "seized": 1,
#     "boat": 1,
#     "bound": 1,
#     "525": 1,
#     "expensive": 1,
#     "asian": 1,
#     "cuisine": 1,
#     "delicacy": 1,
#     "value": 1,
#     "\u00a3": 1,
#     "370,000": 1,
#     "step": 1,
#     "cija": 1,
#     "heavy": 1,
#     "incriminating": 1,
#     "carrier": 1,
#     "portable": 1,
#     "authenticate": 1,
#     "bundles": 1,
#     "fifty": 1,
#     "dizzying": 1,
#     "array": 1,
#     "crappy": 1,
#     "suitcases": 1,
#     "wiley": 1,
#     "loads": 1,
#     "intricate": 1,
#     "photocopier": 1,
#     "explained": 1,
#     "bricks": 1,
#     "pages": 1,
#     "weighing": 1,
#     "cape": 1,
#     "courting": 1,
#     "boasts": 1,
#     "celtic": 1,
#     "continent": 1,
#     "neutral": 1,
#     "sailing": 1,
#     "reserves": 1,
#     "mi\u2019kmaq": 1,
#     "features": 1,
#     "road": 1,
#     "trips": 1,
#     "anywhere": 1,
#     "wrath": 1,
#     "billionaire": 1,
#     "estate": 1,
#     "dominica": 1,
#     "caribbean": 1,
#     "obtained": 1,
#     "cyprus": 1,
#     "nationality": 1,
#     "acquired": 1,
#     "mere": 1,
#     "bargain": 1,
#     "basement": 1,
#     "2.8": 1,
#     "..": 1,
#     "teenage": 1,
#     "model": 1,
#     "140": 1,
#     "jealous": 1,
#     "older": 1,
#     "corpse": 1,
#     "17-year": 1,
#     "mutilated": 1,
#     "recognition": 1,
#     "gouged": 1,
#     "ears": 1,
#     "elizaveta": 1,
#     "44-year": 1,
#     "photographer": 1,
#     "st": 1,
#     "identity": 1,
#     "owner": 1,
#     "alcohol": 1,
#     "id": 1,
#     "cards": 1,
#     "omran": 1,
#     "impossible": 1,
#     "chosen": 1,
#     "wrenching": 1,
#     "throngs": 1,
#     "pushing": 1,
#     "promised": 1,
#     "expects": 1,
#     "800,000": 1,
#     "overthrow": 1,
#     "austrian": 1,
#     "austria": 1,
#     "persecuted": 1,
#     "vigorous": 1,
#     "disastrous": 1,
#     "1994": 1,
#     "welfare": 1,
#     "reform": 1,
#     "super": 1,
#     "predators": 1,
#     "1990s": 1,
#     "regret": 1,
#     "attended": 1,
#     "visual": 1,
#     "tweet": 1,
#     "1963": 1,
#     "scranton": 1,
#     "pa.": 1,
#     "memory": 1,
#     "lane": 1,
#     "tour": 1,
#     "detention": 1,
#     "guantanamo": 1,
#     "bay": 1,
#     "highly": 1,
#     "valued": 1,
#     "combatants": 1,
#     "commissions": 1,
#     "deport": 1,
#     "preach": 1,
#     "assimilate": 1,
#     "assimilation": 1,
#     "compassion": 1,
#     "adopt": 1,
#     "journal": 1,
#     "denying": 1,
#     "sympathizers": 1,
#     "athens": 1,
#     "denounce": 1,
#     "slam": 1,
#     "azerbaijan": 1,
#     "escalating": 1,
#     "disputed": 1,
#     "azeri": 1,
#     "embassies": 1,
#     "greek": 1,
#     "reading": 1,
#     "triumph": 1,
#     "\u201d\u201cazerbaijan": 1,
#     "armenia": 1,
#     "participated": 1,
#     "sarkis": 1,
#     "cathedral": 1,
#     "recognize": 1,
#     "uptick": 1,
#     "historical": 1,
#     "accepts": 1,
#     "responsibility": 1,
#     "karen": 1,
#     "khanlari": 1,
#     "iranian": 1,
#     "lawmaker": 1,
#     "ruptly": 1,
#     "regiment": 1,
#     "indian": 1,
#     "forming": 1,
#     "brigade": 1,
#     "deployments": 1,
#     "regiments": 1,
#     "tipu": 1,
#     "sultan": 1,
#     "maharana": 1,
#     "pratap": 1,
#     "aurangazeb": 1,
#     "ladakh": 1,
#     "temperaturescould": 1,
#     "-45": 1,
#     "winter": 1,
#     "smoothly": 1,
#     "barren": 1,
#     "harsh": 1,
#     "weather": 1,
#     "nights": 1,
#     "valleys": 1,
#     "mountain": 1,
#     "ranges": 1,
#     "armoured": 1,
#     "besides": 1,
#     "unnamed": 1,
#     "ndtv": 1,
#     "hole": 1,
#     "sakhour": 1,
#     "abdalrhman": 1,
#     "ismail": 1,
#     "beirut": 1,
#     "intensifying": 1,
#     "feared": 1,
#     "fall": 1,
#     "generals": 1,
#     "determined": 1,
#     "offensives": 1,
#     "advances": 1,
#     "northwest": 1,
#     "torpedo": 1,
#     "geneva": 1,
#     "reduction": 1,
#     "overshadowed": 1,
#     "declaring": 1,
#     "postponed": 1,
#     "opposite": 1,
#     "insurgents": 1,
#     "jihadist": 1,
#     "functioning": 1,
#     "fadela": 1,
#     "functional": 1,
#     "offers": 1,
#     "trauma": 1,
#     "briefing": 1,
#     "sick": 1,
#     "respond": 1,
#     "convoys": 1,
#     "jens": 1,
#     "laerke": 1,
#     "tom": 1,
#     "stephanie": 1,
#     "nebehay": 1,
#     "jack": 1,
#     "stubbs": 1,
#     "michelle": 1,
#     "nichols": 1,
#     "editing": 1,
#     "ralph": 1,
#     "boulton": 1,
#     "angus": 1,
#     "macswan": 1,
#     "flooded": 1,
#     "torn": 1,
#     "popular": 1,
#     "revolt": 1,
#     "arose": 1,
#     "agreements": 1,
#     "concurrent": 1,
#     "suspension": 1,
#     "external": 1,
#     "rendered": 1,
#     "pact": 1,
#     "unworkable": 1,
#     "racists": 1,
#     "wish": 1,
#     "accept": 1,
#     "newcomers": 1,
#     "values": 1,
#     "outlook": 1,
#     "protocols": 1,
#     "essentially": 1,
#     "discarded": 1,
#     "intolerant": 1,
#     "commentary": 1,
#     "gonzalo": 1,
#     "presiding": 1,
#     "prosecutor": 1,
#     "pursuing": 1,
#     "cartels": 1,
#     "fairly": 1,
#     "arguments": 1,
#     "heritage": 1,
#     "'m": 1,
#     "versions": 1,
#     "dad": 1,
#     "impressive": 1,
#     "credits": 1,
#     "village": 1,
#     "shullana": 1,
#     "millatmal": 1,
#     "graduated": 1,
#     "kabul": 1,
#     "1976": 1,
#     "tortured": 1,
#     "communist": 1,
#     "mujahadim": 1,
#     "invasion": 1,
#     "extremism": 1,
#     "fighter": 1,
#     "compelled": 1,
# ...
#     "announcing": 1,
#     "bernardino": 1,
#     "prone": 1,
#     "jacob": 1,
#     "signaling": 1,
#     "coordination": 1,
#     "hrc": 1,
#     "apprenticeships": 1,
#     "minimum": 1,
#     "cnbc": 1,
#     "harwood": 1,
#     "bernie": 1,
#     "departs": 1,
#     "hill": 1,
#     "jane": 1,
#     "jonathan": 1,
#     "ernst": 1,
#     "votes": 1,
#     "populations": 1,
#     "fault": 1,
#     "1,500": 1,
#     "infections": 1,
#     "nenets": 1,
#     "quarantined": 1,
#     "risk": 1,
#     "nomadic": 1,
#     "herders": 1,
#     "anna": 1,
#     "popova": 1,
#     "sanitary": 1,
#     "doctor": 1,
#     "vaccination": 1,
#     "closed": 1,
#     "rejected": 1,
#     "prepared": 1,
#     "imminent": 1,
#     "happens": 1,
#     "crafted": 1,
#     "reject": 1,
#     "nordic": 1,
#     "anchored": 1,
#     "majeure": 1,
#     "presented": 1,
#     "broad": 1,
#     "tightenings": 1,
#     "criticized": 1,
#     "abc": 1,
#     "hell": 1,
#     "drawn": 1,
#     "eyewitness": 1,
#     "accounts": 1,
#     "saide": 1,
#     "refinery": 1,
#     "teen": 1,
#     "carl": 1,
#     "marsha": 1,
#     "blocked": 1,
#     "opportunities": 1,
#     "ransom": 1,
#     "spirit": 1,
#     "dimmed": 1,
#     "concluded": 1,
#     "meeting": 1,
#     "optimistic": 1,
#     "shared": 1,
#     "transfer": 1,
#     "eventually": 1,
#     "censoring": 1,
#     "content": 1,
#     "amendment": 1,
#     "uninformed": 1,
#     "scaparrotti": 1,
#     "crackdown": 1,
#     "mutiny": 1,
#     "organizations": 1,
#     "shut": 1,
#     "crossroads": 1,
#     "lines": 1,
#     "counterterrorism": 1,
#     "player": 1,
#     "containing": 1,
#     "solution": 1,
#     "proponents": 1,
#     "rooted": 1,
#     "fundamental": 1,
#     "misunderstanding": 1,
#     "iana": 1,
#     "scope": 1,
#     "ntia": 1,
#     "lawrence": 1,
#     "strickling": 1,
#     "36": 1,
#     "mailonline": 1,
#     "booked": 1,
#     "listen": 1,
#     "mr": 1,
#     "electrician": 1,
#     "kyle": 1,
#     "hadden": 1,
#     "43": 1,
#     "gunshots": 1,
#     "management": 1,
#     "witnessed": 1,
#     "attackers": 1,
#     "sneaked": 1,
#     "bella": 1,
#     "vista": 1,
#     "door": 1,
#     "accessing": 1,
#     "facility": 1,
#     "supercharging": 1,
#     "discussing": 1,
#     "reasoned": 1,
#     "reservation": 1,
#     "yahooism": 1,
#     "generates": 1,
#     "quantum": 1,
#     "exceptionalism": 1,
#     "stigmatizes": 1,
#     "rapist": 1,
#     "murderer": 1,
#     "humbug": 1,
#     "implicit": 1,
#     "euphemisms": 1,
#     "theory": 1,
#     "exploded": 1,
#     "blurring": 1,
#     "distinction": 1,
#     "learn": 1,
#     "deemed": 1,
#     "incorrect": 1,
#     "offense": 1,
#     "declare": 1,
#     "stigmatize": 1,
#     "cultural": 1,
#     "unraveling": 1,
#     "damagingly": 1,
#     "demoralized": 1,
#     "fly": 1,
#     "zone": 1,
#     "mainly": 1,
#     "legitimacy": 1,
#     "contribution": 1,
#     "symbolic": 1,
#     "gather": 1,
#     "deserted": 1,
#     "handarat": 1,
#     "bases": 1,
#     "dating": 1,
#     "bones": 1,
#     "prior": 1,
#     "earliest": 1,
#     "bering": 1,
#     "existed": 1,
#     "dr": 1,
#     "pitulko": 1,
#     "gate": 1,
#     "tells": 1,
#     "barbara": 1,
#     "30-second": 1,
#     "begins": 1,
#     "backed": 1,
#     "buy": 1,
#     "always": 1,
#     "brings": 1,
#     "commitment": 1,
#     "represents": 1,
#     "listing": 1,
#     "accomplishments": 1,
#     "heroin": 1,
#     "mom": 1,
#     "http": 1,
#     "//bit.ly/2ce1t9m": 1,
#     "holds": 1,
#     "suffolk": 1,
#     "poll": 1,
#     "gives": 1,
#     "incumbent": 1,
#     "richard": 1,
#     "burr": 1,
#     "modest": 1,
#     "democrat": 1,
#     "deborah": 1,
#     "ross": 1,
#     "senate": 1,
#     "race": 1,
#     "albin": 1,
#     "lohr": 1,
#     "jones": 1,
#     "zuma": 1,
#     "nefarious": 1,
#     "consigliere": 1,
#     "nattily": 1,
#     "dressed": 1,
#     "seersucker": 1,
#     "suit": 1,
#     "suspenders": 1,
#     "bar": 1,
#     "renaissance": 1,
#     "posing": 1,
#     "evil": 1,
#     "witch": 1,
#     "narrowing": 1,
#     "discuss": 1,
#     "meetings": 1,
#     "gathering": 1,
#     "chaired": 1,
#     "nsc": 1,
#     "session": 1,
#     "offensive": 1,
#     "begun": 1,
#     "upcoming": 1,
#     "raqqa": 1,
#     "consideration": 1,
#     "alternatives": 1,
#     "u.s.-allied": 1,
#     "quantity": 1,
#     "quality": 1,
#     "supplied": 1,
#     "deferred": 1,
#     "possibilities": 1,
#     "yard": 1,
#     "approach": 1,
#     "displaying": 1,
#     "systems": 1,
#     "attract": 1,
#     "purchasers": 1,
#     "s-300": 1,
#     "deployment": 1,
#     "gen.": 1,
#     "credited": 1,
#     "restore": 1,
#     "stability": 1,
#     "probation": 1,
#     "pleading": 1,
#     "misdemeanor": 1,
#     "count": 1,
#     "unlawfully": 1,
#     "retaining": 1,
#     "biographer": 1,
#     "romantically": 1,
#     "biography": 1,
#     "advocates": 1,
#     "howled": 1,
#     "preferential": 1,
#     "treatment": 1,
#     "hurled": 1,
#     "unsecure": 1,
#     "completed": 1,
#     "sensitive": 1,
#     "nobody": 1,
#     "oklahoma": 1,
#     "common": 1,
#     "travel": 1,
#     "broke": 1,
#     "highway": 1,
#     "windows": 1,
#     "shake": 1,
#     "nearby": 1,
#     "circulating": 1,
#     "plume": 1,
#     "shattered": 1,
#     "explosion": 1,
#     "verify": 1,
#     "authenticity": 1,
#     "wishing": 1,
#     "establishing": 1,
#     "corridors": 1,
#     "providing": 1,
#     "abandon": 1,
#     "battered": 1,
#     "contested": 1,
#     "decried": 1,
#     "claiming": 1,
#     "depopulate": 1,
#     "strongholds": 1,
#     "collin": 1,
#     "peterson": 1,
#     "minn.": 1,
#     "kyrsten": 1,
#     "sinema": 1,
#     "ariz.": 1,
#     "fear": 1,
#     "steinle": 1,
#     "bureau": 1,
#     "outstanding": 1,
#     "request": 1,
#     "receive": 1,
#     "notification": 1,
#     "prioritized": 1,
#     "statutes": 1,
#     "cement": 1,
#     "makeshift": 1,
#     "clinic": 1,
#     "sobeih": 1,
#     "dogan": 1,
#     "primarily": 1,
#     "ambulances": 1,
#     "arriving": 1,
#     "kilis": 1,
#     "stretchers": 1,
#     "blanket": 1,
#     "adults": 1,
#     "halt": 1,
#     "shelled": 1,
#     "u.s.-backed": 1,
#     "militia": 1,
#     "weekend": 1,
#     "federica": 1,
#     "mogherini": 1,
#     "table": 1,
#     "escalate": 1,
#     "cessation": 1,
#     "instructed": 1,
#     "13": 1,
#     "78-year": 1,
#     "row": 1,
#     "sucker": 1,
#     "punched": 1,
#     "protester": 1,
#     "escorted": 1,
#     "raising": 1,
#     "implicitly": 1,
#     "faced": 1,
#     "chuck": 1,
#     "todd": 1,
#     "host": 1,
#     "nbc": 1,
#     "warring": 1,
#     "grapple": 1,
#     "rows": 1,
#     "intervene": 1,
#     "ugly": 1,
#     "scenes": 1,
#     "rips": 1,
#     "shirt": 1,
#     "tries": 1,
#     "match": 1,
#     "huddle": 1,
#     "jump": 1,
#     "railings": 1,
#     "droves": 1,
#     "chase": 1,
#     "cpr": 1,
#     "performed": 1,
#     "suffers": 1,
#     "marseille": 1,
#     "hack": 1,
#     "d.n.c.": 1,
#     "affinity": 1,
#     "kindred": 1,
#     "temperament": 1,
#     "ominously": 1,
#     "...": 1,
#     "won": 1,
#     "popularity": 1,
#     "dispense": 1,
#     "shithouses": 1,
#     "parody": 1,
#     "bluster": 1,
#     "palaces": 1,
#     "historian": 1,
#     "timothy": 1,
#     "snyder": 1,
#     "puts": 1,
#     "version": 1,
#     "pretends": 1,
#     "complex": 1,
#     "gets": 1,
#     "strength": 1,
#     "cynicism": 1,
#     "emulate": 1,
#     "nor": 1,
#     "principal": 1,
#     "actors": 1,
#     "operating": 1,
#     "ratified": 1,
#     "icc": 1,
#     "rome": 1,
#     "statute": 1,
#     "permanent": 1,
#     "vetoed": 1,
#     "resolution": 1,
#     "referred": 1,
#     "included": 1,
#     "staffing": 1,
#     "horde": 1,
#     "50,000": 1,
#     "depicting": 1,
#     "abused": 1,
#     "defector": 1,
#     "identify": 1,
#     "exhibited": 1,
#     "torture": 1,
#     "systematic": 1,
#     "photographing": 1,
#     "lends": 1,
#     "credence": 1,
#     "inquiry": 1,
#     "assertions": 1,
#     "implicated": 1,
#     "abuses": 1,
#     "ruled": 1,
#     "50": 1,
#     "tax": 1,
#     "bankrupt": 1,
#     "silence": 1,
#     "khodorkovsky": 1,
#     "riches": 1,
#     "fund": 1,
#     "u.s.s.r.": 1,
#     "twenties": 1,
#     "ceo": 1,
#     "tyumen": 1,
#     "1998": 1,
#     "2003": 1,
#     "stint": 1,
#     "zao": 1,
#     "samara": 1,
#     "nafta": 1,
#     "subsidiary": 1,
#     "lukoil": 1,
#     "companies": 1,
#     "partner": 1,
#     "hess": 1,
#     "corporation": 1,
#     "4/14": 1,
#     "5/14": 1,
#     "medecins": 1,
#     "sans": 1,
#     "frontieres": 1,
#     "msf": 1,
#     "-backed": 1,
#     "quds": 1,
#     "6/14": 1,
#     "7/14": 1,
#     "bustan": 1,
#     "qasr": 1,
#     "resurfaced": 1,
#     "75": 1,
#     "salekhard": 1,
#     "nenetsk": 1,
#     "boy": 1,
#     "90": 1,
#     "sure": 1,
#     "intestinal": 1,
#     "disease": 1,
#     "harder": 1,
#     "diagnose": 1,
#     "yamal": 1,
#     "tass": 1,
#     "erratic": 1,
#     "blows": 1,
#     "humiliated": 1,
#     "mate": 1,
#     "sparkling": 1,
#     "above": 1,
#     "fray": 1,
#     "seeming": 1,
#     "calm": 1,
#     "poised": 1,
#     "rival": 1,
#     "interrupted": 1,
#     "pugilistic": 1,
#     "rallying": 1,
#     "task": 1,
#     "staunch": 1,
#     "bleeding": 1,
#     "winning": 1,
#     "practically": 1,
#     "prospect": 1,
#     "produced": 1,
#     "mobile": 1,
#     "fitted": 1,
#     "mannequins": 1,
#     "regulating": 1,
#     "thermostats": 1,
#     "heat": 1,
#     "signature": 1,
#     "humans": 1,
#     "allowing": 1,
#     "evade": 1,
#     "scanning": 1,
#     "machines": 1,
#     "trained": 1,
#     "variety": 1,
#     "train": 1,
#     "trainer": 1,
#     "unedited": 1,
#     "remnants": 1,
#     "headed": 1,
#     "passed": 1,
#     "material": 1,
#     "importance": 1,
#     "mine": 1,
#     "aerial": 1,
#     "identified": 1,
#     "pieced": 1,
#     "random": 1,
#     "reveal": 1,
#     "factories": 1,
#     "churn": 1,
#     "finished": 1,
#     "kingdom": 1,
#     "lease": 1,
#     "1.5": 1,
#     "acres": 1,
#     "developed": 1,
#     "farms": 1,
#     "countered": 1,
#     "businessman": 1,
#     "lose": 1,
#     "tell": 1,
#     "confidence": 1,
#     "easily": 1,
#     "accommodate": 1,
#     "imposing": 1,
#     "ancestors": 1,
#     "greater": 1,
#     "impose": 1,
#     "anyone": 1,
#     "sketch": 1,
#     "deportations": 1,
#     "regulatory": 1,
#     "businesses": 1,
#     "introduce": 1,
#     "bureaucracies": 1,
#     "smallest": 1,
#     "transactions": 1,
#     "underclass": 1,
#     "disaffected": 1,
#     "enclaves": 1,
#     "raise": 1,
#     "expand": 1,
#     "cost": 1,
#     "localities": 1,
#     "spark": 1,
#     "disruptive": 1,
#     "riots": 1,
#     "impoverished": 1,
#     "rely": 1,
#     "remittances": 1,
#     "poorer": 1,
#     "sometimes": 1,
#     "neighbor": 1,
#     "existent": 1,
#     "benefits": 1,
#     "ostensible": 1,
#     "obvious": 1,
#     "ferociously": 1,
#     "damaging": 1,
#     "revealed": 1,
#     "teens": 1,
#     "wrongly": 1,
#     "park": 1,
#     "jogger": 1,
#     "undisputable": 1,
#     "dna": 1,
#     "misses": 1,
#     "inflame": 1,
#     "racial": 1,
#     "hatreds": 1,
#     "divisions": 1,
#     "stretch": 1,
#     "democracy": 1,
#     "suggesting": 1,
#     "honor": 1,
#     "results": 1,
#     "denounced": 1,
#     "savage": 1,
#     "deliberate": 1,
#     "analysis": 1,
#     "lorries": 1,
#     "crescent": 1,
#     "warehouse": 1,
#     "warplanes": 1,
#     "backs": 1,
#     "asks": 1,
#     "quizzes": 1,
#     "bows": 1,
#     "prayer": 1,
#     "admit": 1,
#     "alawites": 1,
#     "offshoot": 1,
#     "sect": 1,
#     "lay": 1,
#     "dirt": 1,
#     "anbar": 1,
#     "mid": 1,
#     "informing": 1,
#     "authorized": 1,
#     "lesson": 1,
#     "shoulder": 1,
#     "pulling": 1,
#     "fell": 1,
#     "somewhat": 1,
#     "stumbling": 1,
#     "0:35": 1,
#     "0:55": 1,
#     "precise": 1,
#     "reacts": 1,
#     "breitbart": 1,
#     "photographed": 1,
#     "smiling": 1,
#     "creating": 1,
#     "modes": 1,
#     "delivery": 1,
#     "humanly": 1,
#     "blaming": 1,
#     "again": 1,
#     "revive": 1,
#     "excuse": 1,
#     "possibly": 1,
#     "absolute": 1,
#     "catastrophe": 1,
#     "stumble": 1,
#     "crazy": 1,
#     "circular": 1,
#     "firing": 1,
#     "squad": 1,
#     "purposes": 1,
#     "dragged": 1,
#     "worth": 1,
#     "let": 1,
#     "discretionary": 1,
#     "income": 1,
#     "taxes": 1,
#     "catastrophic": 1,
#     "wars": 1,
#     "oktyabrskoye": 1,
#     "pole": 1,
#     "except": 1,
#     "shouting": 1,
#     "doubting": 1,
#     "excusing": 1,
#     "okay": 1,
#     "spew": 1,
#     "paranoia": 1,
#     "crossed": 1,
#     "scary": 1,
#     "types": 1,
#     "slurs": 1,
#     "hatred": 1,
#     "glibly": 1,
#     "casually": 1,
#     "localization": 1,
#     "193": 1,
#     "stored": 1,
#     "tech": 1,
#     "sector": 1,
#     "tends": 1,
#     "cybersecurity": 1,
#     "platform": 1,
#     "formally": 1,
#     "endorses": 1,
#     "researchers": 1,
#     "shunning": 1,
#     "whatsapp": 1,
#     "telegram": 1,
#     "communications": 1,
#     "ordered": 1,
#     "unlock": 1,
#     "iphone": 1,
#     "fingerprint": 1,
#     "unknown": 1,
#     "hijacking": 1,
#     "scheme": 1,
#     "keys": 1,
#     "prison": 1,
#     "appeals": 1,
#     "quick": 1,
#     "bytes": 1,
#     "worried": 1,
#     "pokemon": 1,
#     "jazeera": 1,
#     "bernard": 1,
#     "doha": 1,
#     "freeze": 1,
#     "exported": 1,
#     "crude": 1,
#     "landmark": 1,
#     "powers": 1,
#     "quoted": 1,
#     "rokneddin": 1,
#     "deputy": 1,
#     "marked": 1,
#     "chapter": 1,
#     "export": 1,
#     "spain": 1,
#     "planned": 1,
#     "add": 1,
#     "3.1": 1,
#     "barrels": 1,
#     "bpd": 1,
#     "blamed": 1,
#     "edward": 1,
#     "relationship": 1,
#     "hosts": 1,
#     "speculation": 1,
#     "hawaii": 1,
#     "purloined": 1,
#     "sheremetyevo": 1,
#     "representatives": 1,
#     "met": 1,
#     "sojourn": 1,
#     "lasted": 1,
#     "celebrated": 1,
#     "30th": 1,
#     "consulate": 1,
#     "engaged": 1,
#     "gymnastics": 1,
#     "terming": 1,
#     "disasters": 1,
#     "missions": 1,
#     "contingency": 1,
#     "ford": 1,
#     "hood": 1,
#     "workplace": 1,
#     "virus": 1,
#     "infected": 1,
#     "speak": 1,
#     "enemy": 1,
#     "wonder": 1,
#     "everywhere": 1,
#     "employment": 1,
#     "junior": 1,
#     "varsity": 1,
#     "jihadis": 1,
#     "networks": 1,
#     "globe": 1,
#     "design": 1,
#     "flurry": 1,
#     "abandoning": 1,
#     "extraordinarily": 1,
#     "bad": 1,
#     "disparaged": 1,
#     "star": 1,
#     "unfit": 1,
#     "woefully": 1,
#     "unprepared": 1,
#     "endorse": 1,
#     "speaker": 1,
#     "ryan": 1,
#     "primaries": 1,
#     "falsely": 1,
#     "m": 1,
#     "ejected": 1,
#     "crying": 1,
#     "accepted": 1,
#     "purple": 1,
#     "veteran": 1,
#     "harassed": 1,
#     "appeared": 1,
#     "unaware": 1,
#     "invaded": 1,
#     "melania": 1,
#     "nude": 1,
#     "republished": 1,
#     "rewarded": 1,
#     "mightily": 1,
#     "30,000": 1,
#     "indictment": 1,
#     "james": 1,
#     "comey": 1,
#     "seemed": 1,
#     "hint": 1,
#     "counting": 1,
#     "tampering": 1,
#     "obstruction": 1,
#     "deleting": 1,
#     "troubling": 1,
#     "deleted": 1,
#     "touting": 1,
#     "reward": 1,
#     "turning": 1,
#     "fail": 1,
#     "opened": 1,
#     "nonetheless": 1,
#     "pundits": 1,
#     "memo": 1,
#     "serving": 1,
#     "contrast": 1,
#     "copious": 1,
#     "demonstrable": 1,
#     "infractions": 1,
#     "sketchy": 1,
#     "circumstantial": 1,
#     "convict": 1,
#     "lend": 1,
#     "weight": 1,
#     "rich": 1,
#     "powerful": 1,
#     "cryptic": 1,
#     "tweets": 1,
#     "designed": 1,
#     "computer": 1,
#     "journalist": 1,
#     "intercept": 1,
#     "elaborate": 1,
#     "sputnik": 1,
#     "strange": 1,
#     "64-character": 1,
#     "indicate": 1,
#     "automatically": 1,
#     "holder": 1,
#     "perform": 1,
#     "acknowledged": 1,
#     "distributed": 1,
#     "journalists": 1,
#     "associates": 1,
#     "brief": 1,
#     "twitter": 1,
#     "followers": 1,
#     "sleuth": 1,
#     "mode": 1,
#     "decipher": 1,
#     "meaning": 1,
#     "sieges": 1,
#     "collapse": 1,
#     "suburbs": 1,
#     "evacuations": 1,
#     "unrelenting": 1,
#     "starved": 1,
#     "resorted": 1,
#     "grass": 1,
#     "subjected": 1,
#     "onslaught": 1,
#     "emerged": 1,
#     "muadhamiya": 1,
#     "suburb": 1,
#     "future": 1,
#     "neoliberals": 1,
#     "everyone": 1,
#     "disposable": 1,
#     "risen": 1,
#     "herald": 1,
#     "neoliberal": 1,
#     "driven": 1,
#     "greed": 1,
#     "traffickers": 1,
#     "smugglers": 1,
#     "pirates": 1,
#     "kidnappers": 1,
#     "militias": 1,
#     "huge": 1,
#     "swaths": 1,
#     "territory": 1,
#     "vanished": 1,
#     "globalization": 1,
#     "nihilists": 1,
#     "corporate": 1,
#     "naked": 1,
#     "cruder": 1,
#     "parallel": 1,
#     "dominate": 1,
#     "statistics": 1,
#     "lost": 1,
#     "buried": 1,
#     "nearest": 1,
#     "cemetery": 1,
#     "scharipow": 1,
#     "alone": 1,
#     "arranges": 1,
#     "tajikistan": 1,
#     "countrymen": 1,
#     "fracht-200": 1,
#     "coffin": 1,
#     "zinc": 1,
#     "1,300": 1,
#     "die": 1,
#     "scharipov": 1,
#     "sulaimon": 1,
#     "saidov": 1,
#     "alive": 1,
#     "considerable": 1,
#     "disabilities": 1
# }

# %%
keywords = {
    'movement.transportartifact.nonviolentthrowlaunch': ['threw', 'hurl', 'flung', 'throw', 'fling', 'heave'],
    'life.die.deathcausedbyviolentevents': ['death', 'war', 'kill', 'genocide', 'attack', 'shoot', 'massacre', 'die', 'shot', 'homicide', 'execut', 'slay', 'slain', 'violence', 'murder', 'assassinat', 'slaughter', 'dead', 'bombing', 'assault', 'decapitat', 'drown', 'fatal', 'exterminat', 'holocaust'],
    'movement.transportartifact.hide': ['smuggl', 'conceal'],
    'conflict.attack.selfdirectedbattle': ['war', 'fight', 'kill', 'coup', 'attack', 'conflict', 'clash', 'bomb', 'combat', 'strike', 'massacr', 'assault', 'battle', 'annihilat', 'slaughter', 'skirmish', 'assail', 'aggress'],
    'life.injure.illnessdegradationphysical': ['disease', 'illness', 'sick', 'surger', 'condition', 'fever'],
    'contact.commitmentpromiseexpressintent.n/a': ['pledg', 'promise', 'vow', 'oath'],
    'justice.arrestjaildetain.arrestjaildetain': ['detain', 'arrest', 'prison', 'capture', 'incarcerat', 'crime', 'jail'],
    'contact.discussion.meet': ['debate', 'interview', 'meet', 'met', 'talk', 'question', 'convene', 'discuss', 'dialogue', 'negotiat', 'confer'],
    'life.injure.injurycausedbyviolentevents': ['attack', 'kill', 'assault', 'injur', 'wound', 'shoot', 'shot', 'tortur', 'violen', 'rape', 'raping', 'strik', 'death', 'crime', 'punch', 'bruis', 'harm', 'hurt', 'kick', 'brutal', 'shed blood', 'mutilate'],
    'personnel.endposition.n/a': ['retir', 'resign', 'oust', 'fir', 'quit', 'dismiss', 'discharg', 'layoff', 'sack'],
    'transaction.transferownership.n/a': ['donat', 'auction', 'purchas', 'acquire', 'stolen', 'buy', 'loan', 'lend', 'lent', 'provid', 'rent', 'borrow', 'grant', 'obtain', 'bought', 'fund', 'embargo', 'sanction'],
    'justice.investigate.investigatecrime': ['investigat'],
    'contact.collaborate.n/a': ['email', 'told', 'telephone', 'meet', 'congregate', 'fax', 'met'],
    'government.agreements.violateagreement': ['ceasefire', 'agreement', 'violat', 'treaty', 'met'],
    'movement.transportperson.prevententry': ['denied', 'obstruct', 'block'],
    'contact.commandorder.broadcast': ['demand', 'command', 'urg'],
    'transaction.transfermoney.n/a': ['pay', 'purchas', 'buy', 'rent', 'lend', 'loan', 'lent', 'reimburs', 'sanction', 'fund', 'donate', 'borrow', 'bought', 'provid', 'acquir', 'compensat', 'auction', 'paid', 'stipend', 'income', 'donat', 'embargo', 'boycott'],
    'justice.initiatejudicialprocess.n/a': ['charg', 'trial', 'proceed', 'accus', 'testif', 'indict'],
    'contact.prevarication.broadcast': ['lie', 'deciev', 'mislead', 'misled', 'deceive'],
    'conflict.attack.stealrobhijack': ['rob', 'hijack', 'commandeer'],
    'life.injure.illnessdegradationhungerthirst': ['starv', 'dehydrat'],
    'contact.negotiate.meet': ['debate', 'negotiat'],
    'contact.threatencoerce.n/a': ['threaten', 'intimidat', 'blackmail'],
    'contact.commitmentpromiseexpressintent.broadcast': ['vow', 'pledg', 'oath', 'promis'],
    'personnel.elect.n/a': ['elect'],
    'transaction.transfermoney.purchase': ['purchas', 'buy', 'bought', 'auction', 'obtain', 'acquir'],
    'contact.mediastatement.broadcast': ['preach', 'broadcast', 'address'],
    'contact.requestadvise.correspondence': ['urg', 'recommend', 'advocat', 'suggest', 'advis'],
    'movement.transportartifact.disperseseparate': ['shipment', 'transport', 'freight'],
    'government.legislate.legislate': ['abolish', 'sign', 'enact', 'vot', 'legislat'],
    'movement.transportperson.preventexit': ['imprison', 'detain', 'captur', 'arrest', 'incarcerat', 'jail'],
    'contact.negotiate.n/a': ['negotiat', 'debat'],
    'government.agreements.n/a': ['agreement', 'treat', 'ceasefire'],
    'life.injure.n/a': ['assault', 'harm', 'kick', 'shot', 'shoot', 'starv', 'wound', 'rape', 'dehydrat', 'punch', 'bruis', 'attack', 'violen', 'injur', 'strik', 'brutaliz', 'hurt', 'sick', 'ill', 'tortur', 'whip', 'fever', 'surgery'],
    'justice.judicialconsequences.extradite': ['extradit'],
    'personnel.endposition.firinglayoff': ['oust', 'fir', 'discharg', 'sack', 'layoff', 'dismiss'],
    'justice.investigate.n/a': ['investigat'],
    'movement.transportartifact.sendsupplyexport': ['suppl', 'export'],
    'government.agreements.acceptagreementcontractceasefire': ['agreement', 'treat', 'ceasefire'],
    'disaster.fireexplosion.fireexplosion': ['fire', 'explosion', 'blaz', 'explod'],
    'contact.collaborate.correspondence': ['fax', 'email', 'telephon'],
    'transaction.transaction.transfercontrol': ['grab', 'seiz', 'confiscat', 'transfer'],
    'transaction.transfermoney.giftgrantprovideaid': ['donat', 'provid', 'fund', 'grant'],
    'movement.transportartifact.nonviolentthrowlaunch': ['heav', 'throw', 'threw', 'flung', 'hurl', 'fling'],
    'contact.commitmentpromiseexpressintent.correspondence': ['vow', 'promis', 'pledg', 'oath'],
    'conflict.attack.airstrikemissilestrike': ['airstrike', 'bombard'],
    'government.formation.n/a': ['take over', 'annex', 'establish', 'took over', 'inaugurat'],
    'movement.transportperson.hide': ['conceal', 'smuggl'],
    'justice.judicialconsequences.execute': ['death penalt', 'execut'],
    'transaction.transaction.embargosanction': ['boycot', 'sanction', 'embargo', 'injunction'],
    'conflict.attack.stabbing': ['stab', 'gouge'],
    'conflict.yield.retreat': ['withdraw', 'retreat', 'withdrew'],
    'transaction.transfermoney.embargosanction': ['sanction', 'boycott', 'embargo', 'injunction'],
    'manufacture.artifact.build': ['construct', 'buil', 'assembl'],
    'inspection.sensoryobserve.n/a': ['inspect', 'immigrat', 'elect', 'vot'],
    'justice.initiatejudicialprocess.trialhearing': ['proceed', 'testif', 'trial'],
    'movement.transportartifact.smuggleextract': ['smuggl', 'traffick'],
    'contact.requestadvise.broadcast': ['advocat', 'recommend', 'advis', 'urg', 'suggest'],
    'contact.commitmentpromiseexpressintent.meet': ['promis', 'vow', 'pledg', 'promis', 'oath'],
    'government.spy.spy': ['spy', 'spie', 'surveillanc'],
    'government.vote.violationspreventvote': ['voter intimidation', 'vot'],
    'contact.discussion.n/a': ['interview', 'dialogue', 'meet', 'convene', 'debat', 'met', 'discuss', 'negotiat', 'confer'],
    'contact.commandorder.correspondence': ['command', 'urg', 'demand'],
    'justice.judicialconsequences.n/a': ['extradit', 'convict', 'execut', 'death penalty', 'guilty'],
    'conflict.attack.firearmattack': ['shoot', 'shot', 'firefight'],
    'contact.prevarication.correspondence': ['misldead', 'deceiv', 'lying', 'lie', 'mislead', 'misled'],
    'movement.transportartifact.bringcarryunload': ['shipment', 'transport', 'freight'],
    'conflict.attack.strangling': ['strangl'],
    'contact.requestadvise.n/a': ['advis', 'advocat', 'recommend', 'urg', 'suggest'],
    'artifactexistence.damagedestroy.destroy': ['destroy', 'eradicat', 'demolish', 'ransack'],
    'life.die.n/a': ['shot', 'deceas', 'slain', 'fatal', 'kill', 'perish', 'massacre', 'die', 'murder', 'shoot', 'execut', 'assassinat', 'genocid', 'death', 'homicide', 'slaughter', 'decapitat', 'drown', 'exterminate', 'passed away', 'holocaust'],
    'contact.threatencoerce.meet': ['intimidat', 'blackmail', 'threaten'],
    'personnel.startposition.hiring': ['hir', 'employ', 'appoint', 'recruit'],
    'conflict.attack.n/a': ['attack', 'strik', 'assault',' hijack', 'rob', 'stab', 'coup', 'fight', 'invad', 'war', 'massacr', 'hang', 'combat', 'bombard', 'slaughter', 'assail', 'kill', 'shoot', 'violence', 'clash', 'explo', 'blaz', 'skirmish', 'battl', 'strangl', 'bomb', 'annihilat', 'blast', 'poison', 'encroach', 'aggress', 'arson', 'gouge', 'hung', 'inferno'],
    'personnel.endposition.quitretire': ['quit', 'retir', 'resign'],
    'justice.initiatejudicialprocess.chargeindict': ['indict', 'accus', 'charg'],
    'contact.requestadvise.meet': ['urg', 'advis', 'recommend', 'suggest', 'advocat'],
    'government.formation.startgpe': ['inaugurat',' establish'],
    'transaction.transfermoney.payforservice': ['reimburs', 'compensat', 'pay', 'incom', 'paid', 'wage', 'stipend'],
    'personnel.elect.winelection': ['win', 'won', 'elect'],
    'movement.transportperson.grantentryasylum': ['immigrat', 'asylum', 'migrat'],
    'movement.transportartifact.n/a': ['suppli', 'supply', 'flung', 'import', 'ship', 'hurl', 'traffick', 'smuggl', 'freight', 'plung', 'bring', 'brought', 'transport', 'export', 'fling', 'obstruct', 'throw', 'detain', 'incarcerate', 'plummet', 'conceal', 'imprison'],
    'contact.publicstatementinperson.broadcast': ['iterat', 'proclaim', 'announc', 'propos', 'profess'],
    'contact.discussion.correspondence': ['conven', 'interview', 'discus', 'confer', 'meet', 'debat', 'negotiat', 'dialogue'],
    'movement.transportperson.disperseseparate': ['shipment', 'transport', 'freight'],
    'transaction.transferownership.purchase': ['acquir', 'purchas', 'obtain', 'buy', 'auction', 'bought'],
    'movement.transportperson.n/a': ['fled', 'escape', 'flee', 'migrat', 'plummet', 'transport', 'traffick', 'evacuat', 'asylum', 'smuggl', 'walk', 'roam', 'incarcerate', 'stumbl', 'unload', 'capture', 'imprison', 'march', 'detain', 'jail', 'plung', 'shipment', 'arrest', 'conceal', 'entry'],
    'conflict.demonstrate.n/a': ['protest'],
    'conflict.demonstrate.marchprotestpoliticalgathering': ['protest'],
    'movement.transportperson.smuggleextract': ['traffick', 'smuggl'],
    'inspection.sensoryobserve.physicalinvestigateinspect': ['inspect', 'immigrat'],
    'contact.publicstatementinperson.n/a': ['reiterat', 'announc', 'profess', 'proclaim', 'propos'],
    'justice.judicialconsequences.convict': ['convict', 'guilty'],
    'contact.funeralvigil.meet': ['funeral', 'burial'],
    'manufacture.artifact.createmanufacture': ['produc', 'manufactur', 'assembl', 'made', 'create'],
    'conflict.yield.n/a': ['withdraw', 'capitulat', 'retreate', 'surrender', 'retreat', 'pullback'],
    'government.formation.mergegpe': ['annex', 'take over', 'took over', 'taken over', 'taking over'],
    'transaction.transfermoney.borrowlend': ['loan', 'lend', 'borrow', 'rent', 'lent'],
    'transaction.transaction.n/a': ['fund', 'grab', 'donat', 'provid', 'grant', 'seiz', 'confiscat', 'embargo', 'transfer', 'injunction'],
    'transaction.transferownership.embargosanction': ['injunction', 'embargo', 'boycott', 'sanction'],
    'transaction.transaction.giftgrantprovideaid': ['donat', 'grant', 'fund', 'provid'],
    'artifactexistence.damagedestroy.damage': ['damag', 'tor', 'wreck', 'batter', 'vandaliz', 'tear', 'punctur', 'pierc'],
    'contact.prevarication.n/a': ['mislead', 'lie', 'deceiv', 'lying'],
    'government.vote.n/a': ['vot'],
    'conflict.attack.invade': ['invad', 'encroach'],
    'contact.threatencoerce.correspondence': ['intimidat', 'blackmail', 'threaten'],
    'personnel.startposition.n/a': ['hir', 'employ', 'recruit', 'appoint'],
    'contact.funeralvigil.n/a': ['burial', 'funeral'],
    'contact.threatencoerce.broadcast': ['intimidat', 'blackmail', 'threaten'],
    'conflict.attack.biologicalchemicalpoisonattack': ['poison'],
    'conflict.attack.bombing': ['bomb', 'strik', 'struck', 'detonate', 'blast', 'explod'],
    'life.die.nonviolentdeath': ['die', 'decease', 'pass away', 'passed away', 'drown', 'perish', 'passes away'],
    'contact.collaborate.meet': ['met', 'meet', 'congregat'],
    'contact.negotiate.correspondence': ['negotiat', 'debat'],
    'government.agreements.rejectnullifyagreementcontractceasefire': ['agreement', 'treat', 'ceasefire'],
    'disaster.accidentcrash.accidentcrash': ['collision', 'crash', 'collid', 'accident'],
    'transaction.transferownership.borrowlend': ['loan', 'borrow', 'rent', 'lent', 'lend'],
    'movement.transportartifact.preventexit': ['incarcerat', 'arrest', 'jail', 'detain', 'captur', 'imprison'],
    'movement.transportperson.evacuationrescue': ['escap', 'flee', 'fled', 'evacuat'],
    'movement.transportartifact.receiveimport': ['import'],
    'artifactexistence.damagedestroy.n/a': ['vandaliz', 'wreck', 'damag', 'punctur', 'demolish', 'batter', 'torn', 'destroy', 'tear', 'eradicat', 'ransack', 'pierc'],
    'movement.transportartifact.grantentry': ['import', 'bring', 'brought'],
    'government.vote.castvote': ['vot'],
    'contact.commandorder.meet': ['demand', 'urg', 'command'],
    'conflict.yield.surrender': ['capitulat', 'surrender'],
    'contact.commandorder.n/a': ['demand', 'command', 'urg'],
    'contact.prevarication.meet': ['deceiv', 'mislead', 'misled', 'lie', 'lying'],
    'transaction.transferownership.giftgrantprovideaid': ['fund', 'grant', 'provid', 'donat'],
    'manufacture.artifact.n/a': ['produc', 'compos', 'construct', 'manufactur', 'buil', 'creat', 'make', 'made'],
    'inspection.sensoryobserve.inspectpeopleorganization': ['immigrat', 'inspect'],
    'movement.transportperson.bringcarryunload': ['transport', 'unload'],
    'movement.transportartifact.fall': ['plummet', 'transport', 'shipment', 'plung', 'freight'],
    'inspection.sensoryobserve.monitorelection': ['vot', 'election'],
    'movement.transportperson.fall': ['stumbl', 'plummet'],
    'manufacture.artifact.createintellectualproperty': ['compos', 'produc'],
    'contact.mediastatement.n/a': ['broadcast', 'address', 'preach'],
    'conflict.attack.hanging': ['hang', 'hung'],
    'movement.transportartifact.prevententry': ['obstruct', 'denied entry', 'roadblock'],
    'conflict.attack.setfire': ['arson', 'blaze', 'inferno'],
    'movement.transportperson.selfmotion': ['walk', 'roam', 'march']
}

# %%
for ex in all_examples:
    template = ex['templates'][0]
    if template['incident_type'] in keywords:
        if all(not keyword in ex['doctext'].lower() for keyword in keywords[template['incident_type']]):
            print(template)
